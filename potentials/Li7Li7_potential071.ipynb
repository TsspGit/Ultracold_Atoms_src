# %%
__author__ = '@Tssp'
import numpy as np
import matplotlib.pyplot as plt
from potutils.pot import load_potential
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
ref_ticksize = 16
plt.rcParams['xtick.labelsize']=ref_ticksize
plt.rcParams['legend.fontsize']=ref_ticksize
plt.rcParams['ytick.labelsize']=ref_ticksize
plt.rcParams['axes.labelsize']=ref_ticksize * 3/2
plt.rcParams['axes.titlesize']=ref_ticksize * 3/2

# %%
data = load_potential('LiLi_a3Sup071.pot')
R = data[:,0]
V = data[:,1]

# %%
V
# Out:
# array([ 3.36887166e-01,  3.01686697e-01,  2.70164235e-01, ...,
#        -1.93291982e-24, -1.92211062e-24, -1.91137189e-24])

# %%
fig, ax = plt.subplots(figsize=(12,8))
plt.plot(R[25:75], V[25:75])
plt.xlabel(r'$r(u.a)$', x=0.9)
plt.ylabel(r'$V(r)(u.a)$', y=.86)
#plt.xlim(6, 18)
plt.grid()
#plt.legend(['Potential'], fontsize=16)
fig.savefig('Figures/Li7Li7_071pot.png', dpi=200)
