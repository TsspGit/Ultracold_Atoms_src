# %%
__author__ = "@Tssp"
__date__   = "9/10/20"
import numpy as np
import matplotlib.pyplot as plt
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
plt.rcParams['xtick.labelsize']=16
plt.rcParams['ytick.labelsize']=16
plt.rcParams['axes.labelsize']=18
plt.rcParams['axes.titlesize']=18

# %%
def plot_wf(path, fig, ax):
    Data = np.loadtxt(path)
    x = Data[:,0]
    y = Data[:,1]
    wf = Data[:,2]
    global cm
    cm = ax.tricontourf(x, y, wf, cmap='jet')
    #ax.set_xlim(-5000, 5000)
    #ax.set_ylim(-5000, 5000)
    return fig

# %%
path_1007 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1007'
path_1008 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1008'
path_1009 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1009'
path_1010 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1010'
path_1011 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1011'
path_1012 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1012'
path_1013 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1013'
path_1014 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1014'
path_1015 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1015'
path_1016 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1016'
path_1017 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1017'
path_1018 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1018'
path_1019 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1019'
path_1020 = 'Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1020'

# %% [markdown]
# # X axis plots

# %%
fig = plt.subplots(nrows=2, ncols=3, figsize=(10,6))
ax = plt.subplot(2, 3, 1)
plot_wf(path_1007 + '_x1x2.dat', fig, ax)
ax.set_ylabel('$x_2 (a.u)$')
ax.set_title('1007')
ax = plt.subplot(2, 3, 2)
plot_wf(path_1008 + '_x1x2.dat', fig, ax)
ax.set_title('1008')
ax = plt.subplot(2, 3, 3)
plot_wf(path_1009 + '_x1x2.dat', fig, ax)
ax.set_title('1009')
ax = plt.subplot(2, 3, 4)
plot_wf(path_1010 + '_x1x2.dat', fig, ax)
ax.set_title('1010')
ax.set_ylabel('$x_2 (a.u)$')
ax.set_xlabel('$x_1 (a.u)$')
ax = plt.subplot(2, 3, 5)
plot_wf(path_1011 + '_x1x2.dat', fig, ax)
ax.set_title('1011')
ax.set_xlabel('$x_1 (a.u)$')
ax = plt.subplot(2, 3, 6)
plot_wf(path_1012 + '_x1x2.dat', fig, ax)
ax.set_title('1012')
ax.set_xlabel('$x_1 (a.u)$')
cbaxes = fig[0].add_axes([1.05, 0.1, 0.03, 0.8]) 
fig[0].colorbar(cm, ax=fig[1], cax=cbaxes)
plt.tight_layout()
plt.savefig('WF_ix7190_iy4993_iz50_x.png', bbox_inches='tight', dpi=200)
# Out:
# <ipython-input-17-4f750e1ffc46>:27: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # Y axis plots

# %%
fig = plt.subplots(nrows=2, ncols=3, figsize=(10,6))
ax = plt.subplot(2, 3, 1)
plot_wf(path_1007 + '_y1y2.dat', fig, ax)
ax.set_ylabel('$y_2 (a.u)$')
ax.set_title('1007')
ax = plt.subplot(2, 3, 2)
plot_wf(path_1008 + '_y1y2.dat', fig, ax)
ax.set_title('1008')
ax = plt.subplot(2, 3, 3)
plot_wf(path_1009 + '_y1y2.dat', fig, ax)
ax.set_title('1009')
ax = plt.subplot(2, 3, 4)
plot_wf(path_1010 + '_y1y2.dat', fig, ax)
ax.set_title('1010')
ax.set_ylabel('$y_2 (a.u)$')
ax.set_xlabel('$y_1 (a.u)$')
ax = plt.subplot(2, 3, 5)
plot_wf(path_1011 + '_y1y2.dat', fig, ax)
ax.set_title('1011')
ax.set_xlabel('$y_1 (a.u)$')
ax = plt.subplot(2, 3, 6)
plot_wf(path_1012 + '_y1y2.dat', fig, ax)
ax.set_title('1012')
ax.set_xlabel('$y_1 (a.u)$')
cbaxes = fig[0].add_axes([1.05, 0.1, 0.03, 0.8]) 
fig[0].colorbar(cm, ax=fig[1], cax=cbaxes)
plt.tight_layout()
plt.savefig('WF_ix7190_iy4993_iz50_y.png', bbox_inches='tight', dpi=200)
# Out:
# <ipython-input-18-bcf9360a4f37>:27: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # Z axis plots

# %%
fig = plt.subplots(nrows=2, ncols=3, figsize=(10,6))
ax = plt.subplot(2, 3, 1)
plot_wf(path_1007 + '_z1z2.dat', fig, ax)
ax.set_ylabel('$z_2 (a.u)$')
ax.set_title('1007')
ax = plt.subplot(2, 3, 2)
plot_wf(path_1008 + '_z1z2.dat', fig, ax)
ax.set_title('1008')
ax = plt.subplot(2, 3, 3)
plot_wf(path_1009 + '_z1z2.dat', fig, ax)
ax.set_title('1009')
ax = plt.subplot(2, 3, 4)
plot_wf(path_1010 + '_z1z2.dat', fig, ax)
ax.set_title('1010')
ax.set_ylabel('$z_2 (a.u)$')
ax.set_xlabel('$z_1 (a.u)$')
ax = plt.subplot(2, 3, 5)
plot_wf(path_1011 + '_z1z2.dat', fig, ax)
ax.set_title('1011')
ax.set_xlabel('$z_1 (a.u)$')
ax = plt.subplot(2, 3, 6)
plot_wf(path_1012 + '_z1z2.dat', fig, ax)
ax.set_title('1012')
ax.set_xlabel('$z_1 (a.u)$')
cbaxes = fig[0].add_axes([1.05, 0.1, 0.03, 0.8]) 
fig[0].colorbar(cm, ax=fig[1], cax=cbaxes)
plt.tight_layout()
plt.savefig('WF_ix7190_iy4993_iz50_z.png', bbox_inches='tight', dpi=200)
# Out:
# <ipython-input-21-af0171d9f3dd>:27: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
