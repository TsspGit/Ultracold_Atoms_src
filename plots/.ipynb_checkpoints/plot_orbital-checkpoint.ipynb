# %%
__author__ = "@Tssp"
__date__   = "9/10/20"
import numpy as np
import matplotlib.pyplot as plt
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
plt.rcParams['xtick.labelsize']=16
plt.rcParams['ytick.labelsize']=16
plt.rcParams['axes.labelsize']=18
plt.rcParams['axes.titlesize']=18

# %%
D1007 = np.loadtxt('Li7Li7_x10000_y10000_z10000_120rm8g2l60m14_68CM8g1L60M14_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix7190_iy4993_iz50_LiLi_a3Sup_0.70780_sinTnx6_sinTny6_sinTnz6Ag_vsLiLi_int_rm200_CM50_dd_1007agCM1Ag_LEV1007_x1x2.dat')

# %%
x = D1007[:,0]
y = D1007[:,1]
wf = D1007[:,2]

# %%
fig, ax = plt.subplots(figsize=(8,6))
cm = ax.tricontourf(x1, x2, wf, cmap='jet')
fig.colorbar(cm)
ax.set_xlabel('$x_1 (a.u)$')
ax.set_ylabel('$x_2 (a.u)$')
plt.show()
