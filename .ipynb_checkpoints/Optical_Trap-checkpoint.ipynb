# %%
__author__ = "@Tssp"
__date__ = "30/12/20"
import numpy as np
from math import pi
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
ref_ticksize = 16
plt.rcParams['xtick.labelsize']=ref_ticksize
plt.rcParams['legend.fontsize']=ref_ticksize
plt.rcParams['ytick.labelsize']=ref_ticksize
plt.rcParams['axes.labelsize']=ref_ticksize * 3/2
plt.rcParams['axes.titlesize']=ref_ticksize * 3/2

# %% [markdown]
# $$ V(x) = V_0(k x)^2 - \frac{1}{3}V_0(k x)^4 + \frac{2}{45}V_0(k x)^6 $$

# %%
Ix     = 4993 / 6.436409310e15 # Laser intensity in mW/cm2 X
Iy     = 4993 / 6.436409310e15 # Laser intensity in mW/cm2 Y
Iz     = 50 / 6.436409310e15   # Laser intensity in mW/cm2 Z
wL     = 1000 / 0.0529177249   # Wavelength in nm
hbar   = 1                     # Planck reduced Constant
m      = 12789.3927072494/2    # Li mass in a.u
alpha  = 200                   # Polarization a.u
k      = 2*pi/wL
Vx     = alpha * Ix
Vy     = alpha * Iy
Vz     = alpha * Iz
x      = np.linspace(-20000, 20000, 1000)
y      = np.linspace(-20000, 20000, 1000)

# %%
def V(x, k, Vo, m):      #1/3
    return Vo*(k*x)**2 - 1/3*Vo*(k*x)**4 + 2/45*Vo*(k*x)**6

# %%
X, Y = np.meshgrid(x, y)

# %%
V_z = (V(X, k, Vx, m) + V(Y, k, Vy, m))/(np.sqrt(2 * np.abs(Vy)/m) * k)

# %%
fig, ax = plt.subplots(figsize=(8,6))
CS = ax.contourf(X, Y, V_z, 30, cmap='RdGy')
cbar = plt.colorbar(CS)
ax.set_xlabel('$x$ (a.u)')
ax.set_ylabel('$y$ (a.u)')
cbar.ax.set_ylabel('$V_z/\omega_y$', rotation=-90, labelpad=20)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8,6))
CS = ax.contour(X, Y, V_z, levels=[3, 5, 100, 1000, 2000, 3000, 4000, 5000], cmap='RdGy')
ax.clabel(CS, inline=1, fontsize=10)
ax.set_xlabel('$x$ (a.u)')
ax.set_ylabel('$y$ (a.u)')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
cbar.ax.set_ylabel('$V_z/\omega_y$', rotation=-90, labelpad=20)
plt.tight_layout()
plt.savefig('General_figures/Potential_Contour.png', dpi=200)

# %%
fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca(projection='3d')
ax2.plot_surface(X, Y, V_z, cmap='RdGy')
plt.xticks([-20e3, -10e3, 0, 10e3, 20e3])
plt.yticks([-20e3, -10e3, 0, 10e3, 20e3])
plt.xlabel('$x$ (a.u)', labelpad=15)
plt.ylabel('$y$ (a.u)', labelpad=15)
ax2.xaxis.set_minor_locator(AutoMinorLocator())
ax2.yaxis.set_minor_locator(AutoMinorLocator())
ax2.set_zlabel('$V_z[\hbar \omega_y]$', rotation=-90, labelpad=15)
plt.tight_layout()
plt.savefig('General_figures/Potential3d.png', dpi=200)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x, V(x, k, Vx, m)/(np.sqrt(2 * np.abs(Vx)/m) * k), label='$V_x$')
ax.plot(x, V(x, k, Vz, m)/(np.sqrt(2 * np.abs(Vz)/m) * k), label='$V_z$')
ax.set_xlabel('$x$ (a.u)')
ax.set_ylabel('$V[\hbar \omega]$')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
plt.tight_layout()
plt.xlim(-20000, 20000)
plt.legend()
plt.savefig('General_figures/Potential2d.png', dpi=200)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x, V(x, k, Vx, m)/(np.sqrt(2 * np.abs(Vx)/m) * k), 'k', label='$V(r, R)$')
ax.fill_between(x, max(V(x, k, Vx, m)/(np.sqrt(2 * np.abs(Vx)/m) * k)), V(x, k, Vx, m)/(np.sqrt(2 * np.abs(Vx)/m) * k), alpha=0.3)
ax.set_ylabel('$V(r, R)$', y=0.9)
plt.text(0, max(V(x, k, Vx, m)/(np.sqrt(2 * np.abs(Vx)/m) * k))/2, '$\Omega$', fontsize=32)
plt.text(17000, max(V(x, k, Vx, m)/(np.sqrt(2 * np.abs(Vx)/m) * k))/2 - 2000, '$\partial \Omega$', fontsize=32)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
plt.tight_layout()
plt.xticks(())
plt.yticks(())
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.xlim(-20000, 20000)
#plt.savefig('General_figures/Boundary_NonHarm.png', dpi=200)
# Out:
# (-20000.0, 20000.0)

# %% [markdown]
# The boundary $\partial \Omega$ provoques the rm-CM coupling

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x, (Vx*k**2*x**2)/(np.sqrt(2 * np.abs(Vx)/m) * k), 'k', label='$V(r, R)$')
ax.fill_between(x, max((Vx*k**2*x**2)/(np.sqrt(2 * np.abs(Vx)/m) * k)), (Vx*k**2*x**2)/(np.sqrt(2 * np.abs(Vx)/m) * k), alpha=0.3)
ax.set_ylabel('$V(r, R)$', y=0.9)
plt.text(-1000, max((Vx*k**2*x**2)/(np.sqrt(2 * np.abs(Vx)/m) * k))/2, '$\Omega$', fontsize=32)
plt.text(11000, max((Vx*k**2*x**2)/(np.sqrt(2 * np.abs(Vx)/m) * k))/2 - 30, '$\partial \Omega$', fontsize=32)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
plt.tight_layout()
plt.xticks(())
plt.yticks(())
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.xlim(-20000, 20000)
plt.savefig('General_figures/Boundary_Harm.png', dpi=200)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x, -x**2, 'r')
ax.plot(x, 1+100000*x, 'g')
#plt.text(-1000, 50, '$\Omega$', fontsize=32)
#plt.text(13000, 30, '$\partial \Omega$', fontsize=32)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
plt.tight_layout()
#plt.xticks(())
#plt.yticks(())
plt.xlim(-1000, 1000)
plt.ylim(-0.25e9, 0.25e9)
#plt.savefig('General_figures/Boundary_Harm.png', dpi=200)
# Out:
# (-250000000.0, 250000000.0)

# %% [markdown]
# ## Coupling Potential

# %%
def W_fun(x, y, k, Vo, m):
    '''
    Parameters:
    -----------
    x: rel motion coordinate
    y: CM motion coordinate
    '''
    return Vx * (- k**4 * x**2 * y**2 + 1/3*k**6 * x**2 * y**4 + 1/12 * k**6 * x**4 * y**2)/(np.sqrt(2 * np.abs(Vy)/m) * k)

# %%
W = W_fun(X, Y, k, Vx, m)

# %%
fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca(projection='3d')
ax2.plot_surface(X, Y, W, cmap='RdGy')
plt.xticks([-20e3, -10e3, 0, 10e3, 20e3])
plt.yticks([-20e3, -10e3, 0, 10e3, 20e3])
plt.xlabel('$x$ (a.u)', labelpad=15)
plt.ylabel('$X$ (a.u)', labelpad=15)
ax2.xaxis.set_minor_locator(AutoMinorLocator())
ax2.yaxis.set_minor_locator(AutoMinorLocator())
ax2.set_zlabel('$W[\hbar \omega_y]$', rotation=-90, labelpad=15)
plt.tight_layout()
#plt.savefig('General_figures/Potential3d.png', dpi=200)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x, W_fun(x, 4, k, Vx, m)/(np.sqrt(2 * np.abs(Vx)/m) * k), label='$W$')
ax.set_xlabel('$x$ (a.u)')
ax.set_ylabel('$W[\hbar \omega]$')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
plt.tight_layout()
plt.xlim(-20000, 20000)
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(8,6))
CS = ax.contour(X, Y, W, levels=[1, 5, 100, 1000, 2000, 3000, 4000, 5000], cmap='RdGy')
ax.clabel(CS, inline=1, fontsize=10)
ax.set_xlabel('$x$ (a.u)')
ax.set_ylabel('$y$ (a.u)')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
cbar.ax.set_ylabel('$W/\omega_y$', rotation=-90, labelpad=20)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8,6))
CS = ax.contourf(X, Y, W, 50, cmap='RdGy')
cbar = plt.colorbar(CS)
ax.set_xlabel('$x$ (a.u)')
ax.set_ylabel('$y$ (a.u)')
cbar.ax.set_ylabel('$W/\omega_y$', labelpad=20)
plt.tight_layout()
