# %%
#!/user/bin/env python
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# PLOTTING PROGRAM OF THE LI7-LI7 SPECTRUM FOR THE STUDY OF INNSBRUCK EXPERIMENT
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# Fabio Revuelta
# Grupo de Sistemas Complejos
# Universidad Politecnica de Madrid
# April 2019
# -----------------------------------------------------------------------------------------
# Preliminaries
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os, fnmatch
from matplotlib.ticker import  MultipleLocator, FormatStrFormatter
from decimal import Decimal
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------

# %%
# Intensity (mW)
Ix = 4993.

# Mass (Da)
mass_Da = 7.0160040
mass = mass_Da * 1822.888457197206133193229
# Polarizability
alpha = 200
# Trap depth (a.u.)
Vx = alpha * Ix / ( 643640931E7 )
# Wave length (nm)
lambda_nm = 1000
# Wave number (a.u.)
a0 = 0.0529177249
kx = 2. * np.pi * a0 / lambda_nm

# Trapping frequency ( a.u. )
hbar = 1.0

wx = np.sqrt( 2.0 * Vx * kx * kx / mass)

w = wx
# -----------------------------------------------------------------------------------------
# Trap length in a.u. 
dx = np.sqrt( 2.0 * hbar / ( mass * w ) )
#d  = dx
#dx = np.sqrt( hbar / ( mass * w ) ) # It is actually a_h
d  = dx 
print('Ix (mW)       : ',  Ix)
print('Ix (a.u.)     : ',  Ix / ( 643640931E7 ) )
print('mass (Da)     : ',  mass_Da)
print('mass (a.u.)   : ',  mass)
print('alpha         : ',  alpha)
print('Vx (a.u.)     : ',  Vx)
print('lambda (nm)   : ',  lambda_nm)
print('kx (a.u.)     : ',  kx)
print('wx (a.u.)     : ',  wx)
print('ah (a.u.)     : ',  dx)
# -----------------------------------------------------------------------------------------
# Scattering length
# Delta    asc (a.u.)
# Out:
# Ix (mW)       :  4993.0
# Ix (a.u.)     :  7.757430827530762e-13
# mass (Da)     :  7.016004
# mass (a.u.)   :  12789.392707249426
# alpha         :  200
# Vx (a.u.)     :  1.5514861655061523e-10
# lambda (nm)   :  1000
# kx (a.u.)     :  0.00033249187158105134
# wx (a.u.)     :  5.1789894062022946e-11
# ah (a.u.)     :  1737.6708872730799

# %%
delta = []
asc   = []

delta.append( Decimal('0.7080')  )
asc.append( 1191.58168082959 )

delta.append( 0.70805 )
asc.append(  1199.73395812338 )

delta.append( 0.7081   )
asc.append(1208.00150021930 )

delta.append( 0.70815  )
asc.append( 1216.38675672344 )

delta.append( 0.7082  )
asc.append( 1224.89227055587 )

delta.append( 0.70825 )
asc.append(  1233.52065585274 )

delta.append( 0.7083   )
asc.append(1242.27458068079 )

delta.append( 0.70835 )
asc.append(  1251.15681153772 )

delta.append( 0.7084  )
asc.append( 1260.17019870601 )

delta.append( 0.70845  )
asc.append( 1269.31764930816 )

delta.append( 0.7085   )
asc.append(1278.60219549329 )

delta.append( 0.70855  )
asc.append( 1288.02693854581 )

delta.append( 0.7086  )
asc.append( 1297.59506832038 )

delta.append( 0.70865  )
asc.append( 1307.30989759343 )

delta.append( 0.7087   )
asc.append(1317.17482778704 )

delta.append( 0.70875  )
asc.append( 1327.19334316745 )

delta.append( 0.7088  )
asc.append( 1337.36908859614 )

delta.append( 0.70885 )
asc.append(  1347.70577729459 )

delta.append( 0.7089  )
asc.append( 1358.20726171416 )

delta.append( 0.70895 )
asc.append(  1368.87751842734 )

delta.append( Decimal('0.7090')  )
asc.append( 1379.72064594415 )

delta.append( 0.70905 )
asc.append(  1390.74087793971 )

delta.append( 0.7091   )
asc.append(1401.94260401253 )

delta.append( 0.70915 )
asc.append(  1413.33032919673 )

delta.append( 0.7092  )
asc.append( 1424.90873625383 )

delta.append( 0.70925 )
asc.append(  1436.68264328870 )

delta.append( 0.7093 )
asc.append(  1448.65706791664 )

delta.append( 0.70935  )
asc.append( 1460.83715304107 )

delta.append( 0.7094 )
asc.append(  1473.22824971113 )

delta.append( 0.70945 )
asc.append(  1485.83590393415 )

delta.append( 0.7095 )
asc.append(  1498.66583449300 )

delta.append( 0.70955  )
asc.append( 1511.72396478758 )

delta.append( 0.7096 )
asc.append(  1525.01645260571 )

delta.append( 0.70965 )
asc.append(  1538.54965309584 )

delta.append( 0.7097  )
asc.append( 1552.33017349492 )

delta.append( 0.70975 )
asc.append(  1566.36484680843 )

delta.append( 0.7098  )
asc.append( 1580.66078690389 )

delta.append( 0.70985 )
asc.append(  1595.22536089131 )

delta.append( 0.7099 )
asc.append(  1610.06618747999 )

delta.append( 0.70995 )
asc.append(  1625.19121772037 )

delta.append( Decimal('0.7100') )
asc.append(  1640.60870394915 )

#delta.append( Decimal('0.7105'))  
#asc.append( 1812.93415170932)

delta.append( 0.7101  )
asc.append( 1672.35561079401 )

delta.append( 0.7102 )
asc.append(  1705.37959037706 )

#delta.append( Decimal('0.7115'))  
#asc.append( 2298.38803849248 )
#
#
L = len(delta)
print
print( 'L : ', L )
# Out:
# L :  43

# %%
np.savetxt('delta_asc.txt', [delta, asc])

# %%
# Plotting parameters
c = 1.75
cm_inc = 32.0/80.0
w_fig = 7 * cm_inc * c
h_fig = w_fig / 1.6
fig, ax = plt.subplots(figsize = (w_fig, h_fig ) )
#fig, ax = plt.subplots(figsize = (1, 1 ) )
#ax.set_aspect(0.621)

# Plotting range
ascmin = np.min( np.abs(asc) ) 
ascmax = np.max( np.abs(asc) ) 

xmin = 1.05
xmax = 1.46
emin =-0.3 #1.5 #-0.3
emax = 3.0 #3.6

# %%
print( 'min(asc) : ', ascmin)
print( 'max(asc) : ', ascmax)
print
print( 'xmin : ', xmin)
print( 'xmax : ', xmax)
print
print( 'emin : ', emin)
print( 'emax : ', emax)
print
# Out:
# min(asc) :  1191.58168082959
# max(asc) :  1705.37959037706
# xmin :  1.05
# xmax :  1.46
# emin :  -0.3
# emax :  3.0
# <function print>

# %%
# Plotting limits
ax.set_xlim([ xmin, xmax] )
ax.set_ylim([ emin, emax] )
# Point size
scattersize = 2

# Labels
labelsize = 15

#ax.set_xlabel('$a_{sc}$\,(a.u.)')
ax.set_xlabel('$a_h/a_{sc}$', fontsize=labelsize)
ax.set_ylabel('$E/(\hbar\,\omega_x)$', fontsize=labelsize)
# Out:
# Text(3.200000000000003, 0.5, '$E/(\\hbar\\,\\omega_x)$')

# %%
file1 = '../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_'
file2 = '_sinTnx6_sinTny6_sinTnz6/'

# %%
# Loop
x_resonance   = []
y_resonance   = []
asc_resonance = []
k=-1

# %%
for i in range(0, L):
    print(i, delta[i], asc[i], d/asc[i])  

    # Input file name
    fileref = file1 + str(delta[i]) + file2
    print(fileref)
    config = os.listdir(fileref)

    for entry in config:
    if fnmatch.fnmatch(entry, '*b.eva'):
    #      configname = entry
      configname = 'Ag_vsLiLi_500-800_75b.eva'

    fileref = fileref + configname
    # print 'fileref : ', fileref

    # Read input file
    data = np.loadtxt(fileref)
    # x = data[:, 0]
    # y = data[:, 2]
    y = data[:, 2]/w
    x = y * 0. + d/asc[i]

    Ly = len(y)
    j = -1
    while j <= Ly:
    j = j + 1
    if y[j] < 0 :
        jref = j
    else:
        break

    j = -1
    k = -1
    while j < Ly-1:
    j = j + 1
    if x[j] >=xmin and x[j] <= xmax and y[j] >= emin and y[j] <= emax :
        k=k+1
        x_resonance.append(x[j])
        y_resonance.append(y[j])
        asc_resonance.append(asc[i])

    print( 'Least bound state :', j, ' E : ', y[jref]*w, ' E/w : ', y[jref])
    print( 'First trap  state :', j+1, ' E : ', y[jref+1]*w, ' E/w : ', y[jref+1])
    print

    plt.scatter(x, y, s = scattersize, c ='k')
# Ticks
ticksize = (2/3)*labelsize
ax.xaxis.set_tick_params( labelsize = ticksize)
ax.yaxis.set_tick_params( labelsize = ticksize)
#tick_params(axis='both',which='major',length=8,width=1.2,direction='in')
#tick_params(axis='both',which='minor',length=5,width=1,direction='in')
tick_params(direction='in')

plt.tight_layout()
# Out:
# 0 0.7080 1191.58168082959 1.4582893604602059
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7080_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -2.217057473848563e-12  E/w :  -0.04280868910821563
# First trap  state : 22575  E :  4.960945244563209e-12  E/w :  0.09578983186607876
# 1 0.70805 1199.73395812338 1.4483801808787167
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70805_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.352857323175439e-12  E/w :  -0.026122033027433374
# First trap  state : 22575  E :  5.8254962434351e-12  E/w :  0.11248326239977546
# 2 0.7081 1208.0015002193 1.438467491106281
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7081_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -4.942069554219886e-13  E/w :  -0.009542536519386049
# First trap  state : 22575  E :  6.684502225204399e-12  E/w :  0.12906962538288108
# 3 0.70815 1216.38675672344 1.428551303825285
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70815_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.411090072865601e-07  E/w :  -2724.643675029914
# First trap  state : 22575  E :  3.589048014134534e-13  E/w :  0.006930016133719706
# 4 0.7082 1224.89227055587 1.418631604626344
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7082_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.408208368429606e-07  E/w :  -2719.079453499466
# First trap  state : 22575  E :  1.206489335437468e-12  E/w :  0.023295844822400893
# 5 0.70825 1233.52065585274 1.4087083820025843
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70825_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.405327233665321e-07  E/w :  -2713.516331935953
# First trap  state : 22575  E :  2.04855800045267e-12  E/w :  0.03955516877480657
# 6 0.7083 1242.27458068079 1.3987816496420649
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7083_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.402446668555043e-07  E/w :  -2707.954310305192
# First trap  state : 22575  E :  2.885122460801699e-12  E/w :  0.05570821321523677
# 7 0.70835 1251.15681153772 1.388851398361022
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70835_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.399566673104807e-07  E/w :  -2702.3933886188356
# First trap  state : 22575  E :  3.716194409100253e-12  E/w :  0.07175520391391
# 8 0.7084 1260.17019870601 1.3789176168880881
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7084_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.396687247400205e-07  E/w :  -2696.833567042152
# First trap  state : 22575  E :  4.541785760248448e-12  E/w :  0.08769637093308708
# 9 0.70845 1269.31764930816 1.3689803243657686
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70845_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.393808391365365e-07  E/w :  -2691.274845428641
# First trap  state : 22575  E :  5.361908443474902e-12  E/w :  0.1035319446116948
# 10 0.7085 1278.60219549329 1.35903949907006
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7085_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.390930105156537e-07  E/w :  -2685.7172240800032
# First trap  state : 22575  E :  6.176574628744053e-12  E/w :  0.11926215993697656
# 11 0.70855 1288.02693854581 1.3490951433321112
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70855_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.388052388704082e-07  E/w :  -2680.160702861773
# First trap  state : 22575  E :  6.985796604830422e-12  E/w :  0.13488725419025413
# 12 0.7086 1297.59506832038 1.3391472653501515
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7086_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.385175242052148e-07  E/w :  -2674.605281859196
# First trap  state : 22575  E :  7.789586787180583e-12  E/w :  0.15040746709873298
# 13 0.70865 1307.30989759343 1.329195847497126
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70865_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.382298665238121e-07  E/w :  -2669.0509611444595
# First trap  state : 22575  E :  8.58795770397752e-12  E/w :  0.16582304056642183
# 14 0.7087 1317.17482778704 1.3192408863389131
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7087_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.379422658309244e-07  E/w :  -2663.497740808785
# First trap  state : 22575  E :  9.380922065139948e-12  E/w :  0.18113422000642576
# 15 0.70875 1327.19334316745 1.3092824012558664
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70875_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.376547221252278e-07  E/w :  -2657.9456208266074
# First trap  state : 22575  E :  1.016849277964714e-11  E/w :  0.1963412546754677
# 16 0.7088 1337.36908859614 1.2993203612154245
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7088_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.373672354071981e-07  E/w :  -2652.3946012071156
# First trap  state : 22575  E :  1.095068279822198e-11  E/w :  0.211444394636289
# 17 0.70885 1347.70577729459 1.2893547809532384
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70885_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.370798056865111e-07  E/w :  -2646.8446821371367
# First trap  state : 22575  E :  1.172750523132126e-11  E/w :  0.22644389303589893
# 18 0.7089 1358.20726171416 1.279385655087728
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7089_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.367924329576702e-07  E/w :  -2641.2958635105383
# First trap  state : 22575  E :  1.24989734691357e-11  E/w :  0.24134000842262934
# 19 0.70895 1368.87751842734 1.2694129780650025
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70895_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.365051172302075e-07  E/w :  -2635.7481455113743
# First trap  state : 22575  E :  1.3265100916614188e-11  E/w :  0.2561329996297746
# 20 0.7090 1379.72064594415 1.2594367507518036
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7090_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.362178585017715e-07  E/w :  -2630.2015280942387
# First trap  state : 22575  E :  1.402590110992275e-11  E/w :  0.2708231280242725
# 21 0.70905 1390.74087793971 1.249456972780813
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70905_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.359306567822266e-07  E/w :  -2624.656011449603
# First trap  state : 22575  E :  1.478138787836687e-11  E/w :  0.2854106606332282
# 22 0.7091 1401.94260401253 1.2394736291626025
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7091_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.35643512062951e-07  E/w :  -2619.1115954109887
# First trap  state : 22575  E :  1.553157512111658e-11  E/w :  0.2998958658327463
# 23 0.70915 1413.33032919673 1.2294867317116798
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70915_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.353564243527614e-07  E/w :  -2613.5682801486364
# First trap  state : 22575  E :  1.62764768630986e-11  E/w :  0.31427901442714073
# 24 0.7092 1424.90873625383 1.2194962688217634
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7092_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.350693936587745e-07  E/w :  -2608.0260657999615
# First trap  state : 22575  E :  1.70161073286154e-11  E/w :  0.3285603810704289
# 25 0.70925 1436.6826432887 1.2095022483847857
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70925_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.347824199745268e-07  E/w :  -2602.484952240161
# First trap  state : 22575  E :  1.775048095630185e-11  E/w :  0.34274024455512675
# 26 0.7093 1448.65706791664 1.1995046486551022
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7093_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.344955033092733e-07  E/w :  -2596.944939647938
# First trap  state : 22575  E :  1.847961218740163e-11  E/w :  0.3568188837241233
# 27 0.70935 1460.83715304107 1.1895034868573247
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70935_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.342086436640642e-07  E/w :  -2591.406028043571
# First trap  state : 22575  E :  1.920351576586232e-11  E/w :  0.3707965832651525
# 28 0.7094 1473.22824971113 1.1794987556163152
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7094_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.339218410353296e-07  E/w :  -2585.8682173581283
# First trap  state : 22575  E :  1.992220655781391e-11  E/w :  0.38467363022514234
# 29 0.70945 1485.83590393415 1.1694904414896214
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70945_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.336350954328912e-07  E/w :  -2580.3315077812563
# First trap  state : 22575  E :  2.06356995040174e-11  E/w :  0.398450313092055
# 30 0.7095 1498.665834493 1.1594785490395434
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7095_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.333484068631267e-07  E/w :  -2574.7958994361
# First trap  state : 22575  E :  2.134400987737273e-11  E/w :  0.4121269267670523
# 31 0.70955 1511.72396478758 1.1494630817189226
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70955_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.330617753186141e-07  E/w :  -2569.2613921793495
# First trap  state : 22575  E :  2.204715300123258e-11  E/w :  0.42570376712547775
# 32 0.7096 1525.01645260571 1.1394440265244479
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7096_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.327752008062499e-07  E/w :  -2563.7279861441684
# First trap  state : 22575  E :  2.274514433099886e-11  E/w :  0.4391811325923847
# 33 0.70965 1538.54965309584 1.129421389668232
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70965_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.324886833282551e-07  E/w :  -2558.195681373441
# First trap  state : 22575  E :  2.343799961703674e-11  E/w :  0.45255932728820947
# 34 0.7097 1552.33017349492 1.1193951627963807
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7097_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.32202222890725e-07  E/w :  -2552.66447798486
# First trap  state : 22575  E :  2.412573460588631e-11  E/w :  0.46583865525953044
# 35 0.70975 1566.36484680843 1.1093653504888705
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70975_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.319158194869163e-07  E/w :  -2547.1343758482208
# First trap  state : 22575  E :  2.480836541212829e-11  E/w :  0.479019427659344
# 36 0.7098 1580.66078690389 1.0993319386866884
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7098_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.316294731296639e-07  E/w :  -2541.60537521135
# First trap  state : 22575  E :  2.548590810435225e-11  E/w :  0.49210195475261326
# 37 0.70985 1595.22536089131 1.0892949233844806
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70985_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.313431838197491e-07  E/w :  -2536.0774760893332
# First trap  state : 22575  E :  2.6158379112759692e-11  E/w :  0.5050865537865888
# 38 0.7099 1610.06618747999 1.079254319347462
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7099_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.310569515532038e-07  E/w :  -2530.5506784055515
# First trap  state : 22575  E :  2.6825794855843353e-11  E/w :  0.5179735417824394
# 39 0.70995 1625.19121772037 1.0692101140630597
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.70995_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.307707763362859e-07  E/w :  -2525.024982280837
# First trap  state : 22575  E :  2.748817210954421e-11  E/w :  0.5307632426632252
# 40 0.7100 1640.60870394915 1.0591622993894212
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7100_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.304846581753809e-07  E/w :  -2519.5003878384855
# First trap  state : 22575  E :  2.814552763143734e-11  E/w :  0.5434559799973833
# 41 0.7101 1672.35561079401 1.039055853944879
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7101_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.299125930245892e-07  E/w :  -2508.4545040584067
# First trap  state : 22575  E :  2.944524187834401e-11  E/w :  0.5685518847186818
# 42 0.7102 1705.37959037706 1.0189349615054795
# ../eva/ix4993_iy4993_iz50/Li7Li7_b_x20000_y20000_z20000_152rm8g2l50m10_102CM8g1L50M10_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix4993_iy4993_iz50_LiLi_a3Sup_0.7102_sinTnx6_sinTny6_sinTnz6/
# Least bound state : 22574  E :  -1.293407561198645e-07  E/w :  -2497.4130274328727
# First trap  state : 22575  E :  3.072507578321324e-11  E/w :  0.593263924162835
