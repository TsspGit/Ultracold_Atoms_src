# %%
__author__ = "@Tssp"
__date__   = "09/02/21"
import numpy as np
import matplotlib.pyplot as plt
import os
from utils.atomic_units import ao, vo, e, hbar, me, Eh, to
from decimal import Decimal
from utils.Energies_Analysis_utils import *
from matplotlib.ticker import AutoMinorLocator
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15
plt.rcParams['axes.labelsize']=18
plt.rcParams['axes.titlesize']=18
aur = (1 + np.sqrt(5)) / 2
aursize = (4.3*aur, 4.3)

# %%
delta = np.loadtxt('Simulations/delta_asc_ix6603.dat', dtype=str)[:,0]
asc = np.loadtxt('Simulations/delta_asc_ix6603.dat')[:,1]
delta = delta.tolist()
asc = asc.tolist()

# %%
# Parameters and Constants:
mass  = 7.0160040 * 1.66053873e-27 / me # a.u
alpha = 200 # a.u
lambd = 1000 * 1e-9 / ao # a.u
ky    = 2*np.pi/lambd
Iy    = 4993 * (1e4 / Eh * to * ao**2)
Vy    = alpha * Iy # a.u
Iy    = Vy/alpha
wy    = np.sqrt( 2 * Vy * ky**2 / mass)       
dho   = np.sqrt(2 / (mass * wy))
print('wy [u.a]: ', wy/to)
print('dho [u.a]: ', dho)
# Out:
# wy [u.a]:  2141065.2804475287
# dho [u.a]:  1737.6709708894564

# %%
print(os.getcwd())
folder_path = "Simulations/ix6042_iy4993_iz50/config/"
# Out:
# /Users/tomy/PhD/Ultracold_Atoms_src/Analysis/q1d

# %%
Data = list()
delta_nonreaded = list()
for d in delta:
    try:
        Data.append(np.loadtxt(folder_path + f'Li7Li7_x18000_y18000_z18000_120rm8g2l60m8_68CM8g1L60M8_Li7a200_Li7a200_kx1000_ky1000_kz1000_ix6042_iy4993_iz50_LiLi_a3Sup_0{d}_sinTnx6_sinTny6_sinTnz6/Ag_vsLiLi_int_rm250_CM50_ddb.eva'))
    except:
        delta_nonreaded.append(d)
        continue
print(f'There are a few folders without data, \ndelta={delta_nonreaded} non readed')
# Out:
# There are a few folders without data,
# delta=['.69000', '.69100', '.69200', '.69300', '.69400', '.69500', '.69600', '.69700', '.69800', '.69900', '.70000', '.70100', '.70200', '.707666', '.707891', '.7081066', '.7083468', '.708483', '.708822', '.7090032', '.7090948', '.7092404', '.7091583', '.71035', '.71040', '.71045', '.71050', '.71055', '.71060', '.71065', '.71070', '.71075', '.71080', '.71085', '.71090', '.71095', '.71100', '.71105', '.71110', '.71115', '.71120', '.71125', '.71130', '.71135', '.71140', '.71145', '.71150', '.71155', '.71160', '.71165', '.71170', '.71175', '.71180', '.71185', '.71190', '.71195', '.71200', '.71205', '.71210', '.71215', '.71220', '.71225', '.71230', '.71235', '.71240', '.71245', '.71250', '.71255', '.71260', '.71265', '.71270', '.71275', '.71280', '.71285', '.71290', '.71295', '.71300', '.71305', '.71310', '.71315', '.71320', '.71325', '.71330', '.71335', '.71340', '.71345', '.71350', '.71355', '.71360', '.71365', '.71370', '.71375', '.71380', '.71385', '.71390', '.71395', '.71400', '.71405', '.71410', '.71415', '.71420', '.71425', '.71430', '.71435', '.71440', '.71445', '.71450', '.71455', '.71460', '.71465', '.71470', '.71475', '.71480', '.71485', '.71490', '.71495', '.71500', '.71505', '.71510', '.71515', '.71520', '.71525', '.71530', '.71535', '.71540', '.71545', '.71550', '.71555', '.71560', '.71565', '.71570', '.71575', '.71580', '.71585', '.71590', '.71595', '.71600', '.71605', '.71610', '.71615', '.71620', '.71625', '.71630', '.71635', '.71640', '.71645', '.71650', '.71655', '.71660', '.71665', '.71670', '.71675', '.71680', '.71685', '.71690', '.71695', '.71700', '.71705', '.71710', '.71715', '.71720', '.71725', '.71730', '.71735', '.71740', '.71745', '.71750', '.71755', '.71760', '.71765', '.71770', '.71775', '.71780', '.71785', '.71790', '.71795', '.71800', '.71900', '.72000', '.72100', '.72200', '.72300', '.72400', '.72500', '.72600', '.72700', '.72800', '.72900', '.73000', '.73100', '.73200', '.73300', '.73400', '.73500', '.73600', '.73700', '.73800'] non readed

# %%
# Delete from original delta and asc lists the unreaded values:
for dnr in delta_nonreaded:
    idx = delta.index(dnr)
    del delta[idx], asc[idx]
assert len(delta) == len(asc)
print("filtering completed")
x = dho / asc
# Out:
# filtering completed

# %%
dic = transpose_energies(Data)

# %%
least_bound_pos = 1052

# %%
fig, ax = plt.subplots(figsize=(8,6))
for i in range(least_bound_pos, least_bound_pos + 100):
    ax.plot(x, dic['nivel_{}'.format(i)]/wy, 'b.')
ax.plot(x, dic['nivel_1056']/wy, 'r')
#ax.plot(x, dic['nivel_1000']/wy, 'r')
ax.set_ylim(0, 3)
ax.set_xlim(1, 2.25)
ax.set_xlabel('$d_{y}/a$')
ax.set_ylabel('$E/\hbar \omega_{y}$')
plt.tight_layout()
#fig.savefig('Results/Figures/Ix4993_Iy4993_Iz50_400_Easc.png', dpi=200)
plt.show()

# %% [markdown]
# # Crosses

# %%
# %matplotlib inline

# %% [markdown]
# ## Resonance x>1

# %%
fig2, ax2 = plt.subplots(figsize=aursize)
xpol = np.linspace(x[0], x[-1], num=50)
for i in range(least_bound_pos+5, least_bound_pos + 29):
    print(i)
    ax2.plot(x, dic['nivel_{}'.format(i)]/wy, 'b')
ax2.plot(x, dic['nivel_1069']/wy, 'r')
ax2.plot(x, dic['nivel_1073']/wy, 'r')
ax2.plot(x, dic['nivel_1079']/wy, 'r')
ax2.plot(x, dic['nivel_1080']/wy, 'r')
ax2.vlines(x[33], 2.059, 2.17, alpha=0.5, linestyles='--')
ax2.vlines(x[26], 2.059, 2.17, alpha=0.5, linestyles='--')
ax2.vlines(x[20], 2.059, 2.17, alpha=0.5, linestyles='--')
ax2.vlines(x[16], 2.059, 2.17, alpha=0.5, linestyles='--')
ax2.vlines(x[9], 2.059, 2.17, alpha=0.5, linestyles='--')
ax2.set_ylim(2.159, 2.166)
ax2.set_xlim(1.9, 2.3)
ax2.set_xlabel('$d_{y}/a$')
ax2.set_ylabel('$E/\hbar \omega_{y}$')
ax2.legend(['Data'], fontsize=14)
#plt.savefig('Results/Figures/Ix4993_Iy4993_Iz4993_Easc_Zoom.png', dpi=200)
plt.show()
# Out:
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080

# %%
print('''f Eigenstates:
1069: trap
1070: (0,2,10)
1071: (0,0,18)
1072: (2,0,10)
1073: (0,4,0) ICIR
1074: (0,2,12)
1075: (0,4,2)
1076: (0,0,20)
1077: (2,0,12)
1078: (0,4,4)
1079: (2,2,0) ICIR
1080: (4,0,0) ICIR
''')
# Out:
# f Eigenstates:
# 1069: trap
# 1070: (0,2,10)
# 1071: (0,0,18)
# 1072: (2,0,10)
# 1073: (0,4,0) ICIR
# 1074: (0,2,12)
# 1075: (0,4,2)
# 1076: (0,0,20)
# 1077: (2,0,12)
# 1078: (0,4,4)
# 1079: (2,2,0) ICIR
# 1080: (4,0,0) ICIR

# %%
print(f'''To find the eigenstates:
x={x[33]}, delta=0{delta[33]}
x={x[26]}, delta=0{delta[26]}
x={x[20]}, delta=0{delta[20]}
x={x[16]}, delta=0{delta[16]}
x={x[9]}, delta=0{delta[9]}''')
# Out:
# To find the eigenstates:
# x=2.114349184038142, delta=0.70465
# x=2.182015554112263, delta=0.70430
# x=2.239885714434933, delta=0.70400
# x=2.278399646901376, delta=0.70380
# x=2.3456721432784238, delta=0.70345

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
fig2, ax2 = plt.subplots(figsize=aursize)
for i in range(least_bound_pos+17, least_bound_pos + 29):
    ax2.plot(x, dic['nivel_{}'.format(i)]/wy, 'b')
ax2.set_ylim(2.16, 2.166)
ax2.set_xlim(1.9, 2.3)
ax2.set_xlabel('$d_{y}/a$')
ax2.set_ylabel('$E/\hbar \omega_{y}$')
ax2.legend(['Data'], fontsize=14)
plt.grid()
xcoord = []
ycoord = []
def onclick(event):
    global ix, iy
    ix, iy = event.xdata, event.ydata
    plt.plot(ix, iy, 'ro', markersize=4)
    plt.draw()
    global xcoord, ycoord
    xcoord.append(ix)
    ycoord.append(iy)
    if len(xcoord) == 30:
        fig2.canvas.mpl_disconnect(cid)
        print(f'xcoord: {xcoord}\n ycoord: {ycoord}')
    return xcoord, ycoord
cid = fig2.canvas.mpl_connect('button_press_event', onclick)
plt.show()
# Out:
# xcoord: [1.9010556055760812, 1.908755316836909, 1.9184420503585953, 1.9291222950107112, 1.941044428575864, 1.9475022509236548, 1.9710981402713528, 1.9827718960538978, 1.9971778074451239, 2.0083548076624544, 2.0210220745754293, 2.032447452575367, 2.051075786270918, 2.065730075444751, 2.080632742401192, 2.0918097426185227, 2.1062156540097488, 2.1161507653140426, 2.1340339656617715, 2.143720699183458, 2.1628457884442236, 2.171787388618088, 2.1814741221397744, 2.196128411313608, 2.2115278338352633, 2.2204694340091278, 2.2286659008351704, 2.2443137011394327, 2.2617001459219472, 2.270890123878419]
#  ycoord: [2.1650077365847618, 2.1649037568855602, 2.1647700687008724, 2.1646215262734416, 2.1644952652101255, 2.1643838583895523, 2.1641090548988053, 2.16393823110726, 2.1637748344370857, 2.163611437766912, 2.163485176703596, 2.1633069257906787, 2.1630989663922757, 2.1629207154793586, 2.1627424645664415, 2.162571640774896, 2.162415671226094, 2.1622894101627774, 2.162088877885746, 2.161970043943801, 2.1617249489385406, 2.1616135421179674, 2.161502135297394, 2.161331311505849, 2.1611233521074458, 2.1610416537723585, 2.160922819830414, 2.1607519960388686, 2.1605143281549792, 2.1604326298198924]

# %%
# %matplotlib inline

# %%
fig3, ax3 = plt.subplots(figsize=aursize)
# nivel 1069:
f1069 = np.polyfit(xcoord, ycoord, deg=1)
x1069 = np.linspace(x.min(), x.max(), num=40)
ax3.plot(x1069, np.polyval(f1069, x1069), 'r--', markersize=4, label='Diabatic')
ax3.plot(x, dic['nivel_1069']/wy, 'b', label='Adiabatic')

# nivel 1070:
ax3.plot(x, dic['nivel_1070']/wy, 'b')

# nivel 1071:
ax3.plot(x, dic['nivel_1071']/wy, 'b')

# nivel 1072:
ax3.plot(x, dic['nivel_1072']/wy, 'b')

# nivel 1073:
ax3.plot(x, dic['nivel_1073']/wy, 'b')
f1073 = np.polyfit(x[(x < 2.11) & (x > 2.09)], np.array(dic['nivel_1073'])[(x < 2.11) & (x > 2.09)]/wy, deg=1)
x1073 = np.linspace(1.95, 2.3, num=200)
ax3.plot(x1073, np.polyval(f1073, x1073), 'r--', markersize=4)

# nivel 1074:
ax3.plot(x, dic['nivel_1074']/wy, 'b')

# nivel 1075:
ax3.plot(x, dic['nivel_1075']/wy, 'b')

# nivel 1076:
ax3.plot(x, dic['nivel_1076']/wy, 'b')

# nivel 1077:
ax3.plot(x, dic['nivel_1077']/wy, 'b')

# nivel 1078:
ax3.plot(x, dic['nivel_1078']/wy, 'b')

# nivel 1079:
ax3.plot(x, dic['nivel_1079']/wy, 'b')
f1079 = np.polyfit(x[(x < 2.27) & (x > 2.25)], np.array(dic['nivel_1079'])[(x < 2.27) & (x > 2.25)]/wy, deg=1)
x1079 = np.linspace(1.95, 2.2, num=200)
ax3.plot(x1079, np.polyval(f1079, x1079), 'r--', markersize=4)


# nivel 1080:
ax3.plot(x, dic['nivel_1080']/wy, 'b')
f1080 = np.polyfit(x[(x < 2.26) & (x > 2.24)], np.array(dic['nivel_1080'])[(x < 2.26) & (x > 2.24)]/wy, deg=1)
x1080 = np.linspace(1.95, 2.2, num=200)
ax3.plot(x1080, np.polyval(f1080, x1080), 'r--', markersize=4)

# Crosses:
##########
ax3.plot(cross_points(f1069, f1073), np.polyval(f1069, cross_points(f1069, f1073)), 'k*', markersize=10, label='ICIR')
ax3.plot(cross_points(f1069, f1079), np.polyval(f1069, cross_points(f1069, f1079)), 'k*', markersize=10)
ax3.plot(cross_points(f1069, f1080), np.polyval(f1069, cross_points(f1069, f1080)), 'k*', markersize=10)


# States:
#########
ax3.annotate(r'$\left|\psi^{(1)} \Phi_{(0,0,0)}\right>$', xy=(1.99, 2.164), xytext=(1.97, 2.1645), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.1, facecolor='r'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.1, facecolor='r'))

#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,0,18)}\right>$', xy=(1.99, 2.061), xytext=(2, 2.061), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.1, facecolor='r'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.1, facecolor='r'))
#
ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(4,0,0)}\right>$', xy=(2.26, 2.163), xytext=(2.13, 2.163), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.1, facecolor='r'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.1, facecolor='r'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,4,0)}\right>$', xy=(2.11, 2.161), xytext=(2, 2.161), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.1, facecolor='r'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.1, facecolor='r'))


#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,0,2)}\right>$', xy=(1.843, 3.38), xytext=(1.80, 3.39), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.1, facecolor='r'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.1, facecolor='r'))
#
#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,2,2)}\right>$', xy=(1.843, 3.38), xytext=(1.85, 3.39), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.1, facecolor='r'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.1, facecolor='r'))
#
ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,2,0)}\right>$', xy=(2.26, 2.164), xytext=(2.13, 2.164), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.1, facecolor='r'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.1, facecolor='r'))


ax3.set_xlabel('$d_{y}/a_{sc}$')
ax3.set_ylabel('$E[\hbar \omega_{y}]$')
#ax3.legend(fontsize=14, bbox_to_anchor=(1.03, 1))
ax3.xaxis.set_minor_locator(AutoMinorLocator())
ax3.yaxis.set_minor_locator(AutoMinorLocator())
ax3.set_ylim(2.16, 2.166)
ax3.set_xlim(1.9, 2.3)
#plt.tight_layout()
#fig3.savefig('Results/Figures/Ix6042_Iy4993_Iz50_Easc_Interpolation_400_v2.png', bbox_inches="tight", dpi=200)
# Out:
# (1.9, 2.3)

# %%
print(f'''Crosses between (x, E):
* 1069-1073: ({cross_points(f1069, f1073)}, {np.polyval(f1069, cross_points(f1069, f1073))})
* 1069-1079: ({cross_points(f1069, f1079)}, {np.polyval(f1069, cross_points(f1069, f1079))})
* 1069-1080: ({cross_points(f1069, f1080)}, {np.polyval(f1069, cross_points(f1069, f1080))})
''')
# Out:
# Crosses between (x, E):
# * 1069-1073: (2.1046627569128624, 2.1624511347898983)
# * 1069-1079: (2.2586538129611964, 2.1605487045527774)
# * 1069-1080: (2.259160969885111, 2.160542439054691)

# %%
print(f'''ICIR: asc/dy:
* 1069-1073 (0,4,0): {1/cross_points(f1069, f1073)} 
* 1069-1079 (2,2,0): {1/cross_points(f1069, f1079)}
* 1069-1080 (4,0,0): {1/cross_points(f1069, f1080)}
''')
# Out:
# ICIR: asc/dy:
# * 1069-1073 (0,4,0): 0.47513550411601746
# * 1069-1079 (2,2,0): 0.4427415986733067
# * 1069-1080 (4,0,0): 0.442642208027724
