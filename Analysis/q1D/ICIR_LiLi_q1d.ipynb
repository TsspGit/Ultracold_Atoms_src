# %%
__author__ = "@Tssp"
__date__ = "21/09/20"
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import os
from utils.atomic_units import ao, vo, e, hbar, me, Eh, to
from decimal import Decimal
from utils.Energies_Analysis_utils import *
from sklearn.metrics import mean_squared_error
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
ref_ticksize = 16
plt.rcParams['xtick.labelsize']=ref_ticksize
plt.rcParams['ytick.labelsize']=ref_ticksize
plt.rcParams['axes.labelsize']=ref_ticksize * 3/2
plt.rcParams['axes.titlesize']=ref_ticksize * 3/2
plt.rcParams['legend.fontsize']=ref_ticksize / (3/2)
aur = (1 + np.sqrt(5))/2
aursize = (4.3*aur, 4.3)

# %%
Data = np.loadtxt('Results/ICIR_q1D.txt')
wxwy = Data[0]
asc_020 = Data[1]
asc_200 = Data[2]

# %%
#wx_wy = list()
#asc_dy = list()
#for f in os.listdir('Results/'):
#    if 'ICIR_positions' in f:
#        print(f)
#        try:
#            wx_wy.extend(np.loadtxt('Results/' + f)[0].tolist())
#            asc_dy.extend(np.loadtxt('Results/' + f)[1].tolist())
#        except:
#            wx_wy.append(np.loadtxt('Results/' + f)[0])
#            asc_dy.append(np.loadtxt('Results/' + f)[1])

# %%
#print(f'wx/wy {wx_wy}\na_cir/dy {asc_dy}')

# %%
#wxwy = [1, 1.05, 1.1, 1.15, 1.2, 1.25]
#ady_up = [0.7722301173376469, 0.7804284076418225, 0.7944225067760224, 0.8061047381064019, 0.8144519605265702, 0.8254722987276476]
#ady_down = [0.7722301173376469, 0.73401877568123, 0.7196919149847377, 0.6958025585502106, 0.6757908502464616, 0.6559715270852553]

# %%
#np.savetxt('Results/ICIR_q1D.txt', [wxwy, ady_up, ady_down], header='wx/wy, asc(020), asc(200)')

# %%
fig, ax = plt.subplots(figsize=aursize)
ax.plot(wxwy, asc_020, 'k*', markersize=8)
ax.plot(wxwy, asc_200, 'k*', markersize=8)
ax.set_xlim(0.997, 1.254)
ax.set_ylim(0.64, 0.83)
ax.set_xlabel('$\omega_x/\omega_y$')
ax.set_ylabel('$a^{ICIR}/d_y$')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
plt.grid()
#fig.savefig('Results/Figures/ICIR_q1d.png', dpi=200)

# %%
#wxwy = np.delete(wxwy, 1)
#wxwy = np.delete(wxwy, 2)
#asc_020 = np.delete(asc_020, 1)
#asc_020 = np.delete(asc_020, 2)
#asc_200 = np.delete(asc_200, 1)
#asc_200 = np.delete(asc_200, 2)

# %%
fig, ax = plt.subplots(figsize=aursize)
ax.plot(wxwy, asc_020, 'k--x')
ax.plot(wxwy, asc_200, 'k--x')
ax.set_xlim(0.997, 1.254)
ax.set_ylim(0.64, 0.83)
ax.set_xlabel('$\omega_x/\omega_y$')
ax.set_ylabel('$a^{ICIR}/d_y$')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
plt.grid()
#fig.savefig('Results/Figures/ICIR_q1d_v2.png', dpi=200)

# %% [markdown]
# # Comparison with Simon

# %%
a_simon_up = [0.772, 0.790, 0.810, 0.819]
a_simon_down = [0.772, 0.716, 0.670, 0.651]

# %%
fig, ax = plt.subplots(figsize=aursize)
ax.plot(wxwy, asc_020, 'k--x', label='Tomy')
ax.plot(wxwy, asc_200, 'k--x')
ax.plot(wxwy, a_simon_up, 'b', label='Simon')
ax.plot(wxwy, a_simon_down, 'b')
ax.set_xlim(0.997, 1.254)
ax.set_ylim(0.64, 0.83)
ax.set_xlabel('$\omega_x/\omega_y$')
ax.set_ylabel('$a_{s}/d_y$')
plt.legend()
plt.grid()
#fig.savefig('Results/Figures/ICIR_q1d_comparison.png', dpi=200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-14bc349ba437> in <module>
#       2 ax.plot(wxwy, asc_020, 'k--x', label='Tomy')
#       3 ax.plot(wxwy, asc_200, 'k--x')
# ----> 4 ax.plot(wxwy, a_simon_up, 'b', label='Simon')
#       5 ax.plot(wxwy, a_simon_down, 'b')
#       6 ax.set_xlim(0.997, 1.254)
#
# ~/Library/Python/3.8/lib/python/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~/Library/Python/3.8/lib/python/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (6,) and (4,)

# %% [markdown]
# # Comparison with Theory

# %%
Data_theory = np.loadtxt('Results/ICIR_q1D_Theory.txt')
wxwy_theory = Data_theory[0]
asc_020_exact = Data_theory[1]
asc_200_exact = Data_theory[2]
asc_020_C0 = Data_theory[3]
asc_200_C0 = Data_theory[4]
asc_020_C1 = Data_theory[5]
asc_200_C1 = Data_theory[6]
asc_020_C2 = Data_theory[7]
asc_200_C2 = Data_theory[8]
asc_020_config = Data_theory[9]
asc_200_config = Data_theory[10]
asc_020_config_C0 = Data_theory[11]
asc_200_config_C0 = Data_theory[12]
asc_020_config_C1 = Data_theory[13]
asc_200_config_C1 = Data_theory[14]
asc_020_config_C2 = Data_theory[15]
asc_200_config_C2 = Data_theory[16]

# %%
wxwy_theory = np.array([1., 1.05, 1.1, 1.15, 1.20, 1.25])
asc_020_C0 = np.array([0.7381847 , 0.74650047, 0.75500356, 0.76375597, 0.77265239, 0.78179139])
asc_200_C0 = np.array([0.7381847 , 0.71001852, 0.68477732, 0.66203735, 0.6413853 , 0.62250154])
asc_020_C1 = np.array([0.7790396 , 0.78863613, 0.79846831, 0.8086072 , 0.81893598, 0.82956819])
asc_200_C1 = np.array([0.7790396 , 0.74633591, 0.71732613, 0.69142145, 0.66808107, 0.64688738])
asc_020_C2 = np.array([0.82696997, 0.83820167, 0.84973663, 0.86165796, 0.87383508, 0.88640123])
asc_200_C2 = np.array([0.82696997, 0.78844406, 0.7546819 , 0.7248461 , 0.69821056, 0.67421869])

# %% [markdown]
# # Eref without coupling

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(wxwy, asc_020, 'k*', markersize=8, label='Ab initio')
ax.plot(wxwy, asc_200, 'k*', markersize=8)
ax.plot(wxwy_theory, asc_020_exact, 'b--', markersize=8, label='Theory C exact')
ax.plot(wxwy_theory, asc_200_exact, 'b--', markersize=8)
ax.plot(wxwy_theory, asc_020_C1, 'r--', markersize=8, label='Theory C=1')
ax.plot(wxwy_theory, asc_200_C1, 'r--', markersize=8)
ax.fill_between(wxwy_theory, asc_020_C0, asc_020_C2, color='dimgray', alpha=0.3, label='Theory $C=0,2$')
ax.fill_between(wxwy_theory, asc_200_C0, asc_200_C2, color='dimgray', alpha=0.3)
ax.set_xlim(0.997, 1.254)
ax.set_ylim(0.62, 0.89)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.set_xlabel('$\omega_x/\omega_y$')
ax.set_ylabel('$a_{s}/d_y$')
plt.legend(fontsize=14, loc='upper left')
plt.tight_layout()
#fig.savefig('Results/Figures/ICIR_q1D_Theory_band_nocoupling.png', dpi=200, bbox_inches="tight")

# %% [markdown]
# # Eref with coupling

# %%
Cup   = [0.81, 0.82, 0.81, 0.83, 0.83, 0.83]
Cdown = [0.81, 0.81, 0.82, 0.80, 0.80, 0.79]
print(f'C(0,4,0): {np.mean(Cup)} +- {np.std(Cup)}\nC(4,0,0): {np.mean(Cdown)} +- {np.std(Cdown)}\nC both: {np.mean([Cup, Cdown])} +- {np.std([Cup, Cdown])}')
# Out:
# C(0,4,0): 0.8216666666666667 +- 0.008975274678557467
# C(4,0,0): 0.805 +- 0.00957427107756336
# C both: 0.8133333333333335 +- 0.012472191289246436

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(wxwy, np.array(asc_020), 'w*', markersize=14, markeredgecolor='k')
ax.plot(wxwy, np.array(asc_200), 'w*', markersize=14, markeredgecolor='k')
ax.plot(wxwy, np.array(asc_020_config_C1), 'darkred', label='$\mathcal{C}=1$')
ax.plot(wxwy, np.array(asc_200_config_C1), 'darkred')
ax.plot(wxwy, np.array(asc_020_config), 'b-', markersize=8, label='$\mathcal{C}=0.52 \pm 0.03$')
ax.plot(wxwy, np.array(asc_200_config), 'b-', markersize=8)
ax.fill_between(wxwy, np.array(asc_020_config_C0), np.array(asc_020_config_C2), color='g', alpha=0.3, \
                label='$\mathcal{C}=\{0,\ 2\}\Phi_{(0,2,0)}$')
ax.fill_between(wxwy, np.array(asc_200_config_C0), np.array(asc_200_config_C2), color='dimgray', alpha=0.3, \
               label='$\mathcal{C}=\{0,\ 2\}\Phi_{(2,0,0)}$')
ax.set_xlim(0.997, 1.254)
ax.set_ylim(0.62, 0.89)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.set_xlabel('$\omega_x/\omega_y$')
ax.set_ylabel('$a_{s}/d_y$')
plt.legend(loc='upper left', frameon=False, ncol=2)
plt.tight_layout()
fig.savefig('Results/Figures/ICIR_q1D_Theory_band_coupling.png', dpi=200, bbox_inches="tight")

# %%
print(f'''
Ab initio vs Exact Theory: {mean_squared_error([asc_020, asc_200], [asc_020_config, asc_200_config])}
Ab initio vs C=1: {mean_squared_error([asc_020, asc_200], [asc_020_config_C1, asc_200_config_C1])}
''')
# Out:
# Ab initio vs Exact Theory: 5.703507722137706e-05
# Ab initio vs C=1: 4.484031270852053e-05

# %% [markdown]
# ## ICIR $\psi_1 \Phi_{0,0,0}$ and $(\psi^{(b)} \Phi_{4,0,0}, \psi^{(b)} \Phi_{0,4,0})$

# %%
wxwy = [1, 1.05, 1.1, 1.15, 1.20, 1.25]
asc_040 = [0.470803168966472, 0.4729586347191949, 0.4751357344614706, 0.47733183136429025, 0.4796684360343298, 0.48194643989803415]
asc_400 = [0.470803168966472, 0.4562712087347454, 0.44274183710072923, 0.43022368344982564, 0.4177549046288673, 0.4076393407999233]

# %%
fig, ax = plt.subplots(figsize=aursize)
plt.plot(wxwy, asc_040, 'k--x')
plt.plot(wxwy, asc_400, 'k--x')
ax.set_xlabel('$\omega_x/\omega_y$')
ax.set_ylabel('$a_{s}/d_y$')
fig.savefig('Results/Figures/ICIR_q1D_400.png', dpi=200, bbox_inches="tight")

# %% [markdown]
# ## ICIR $\psi_1 \Phi_{0,0,0}$ and $(\psi^{(b)} \Phi_{2,2,0}$

# %%
asc_220 = [0.4582885323282912, 0.44841819001129496, 0.4427415986733067, 0.4372803447059619, 0.4320405229549869, 0.4265270475213384]

# %%
fig2, ax2 = plt.subplots(figsize=aursize)
plt.plot(wxwy, asc_220, 'k--x')
ax2.set_xlabel('$\omega_x/\omega_y$')
ax2.set_ylabel('$a_{s}/d_y$')
fig.savefig('Results/Figures/ICIR_q1D_220.png', dpi=200, bbox_inches="tight")
