# %%
__author__ = "@Tssp"
__date__   = "06/10/21"
import numpy as np
import matplotlib.pyplot as plt
import os
from utils.atomic_units import ao, vo, e, hbar, me, Eh, to
from decimal import Decimal
from utils.Energies_Analysis_utils import *
from matplotlib.ticker import AutoMinorLocator
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
ref_ticksize = 16
plt.rcParams['xtick.labelsize']=ref_ticksize
plt.rcParams['ytick.labelsize']=ref_ticksize
plt.rcParams['legend.fontsize']=ref_ticksize
plt.rcParams['axes.labelsize']=ref_ticksize * 3/2
plt.rcParams['axes.titlesize']=ref_ticksize * 3/2
aur = (1 + np.sqrt(5)) / 2
aursize = (5*aur, 5)

# %%
delta = np.loadtxt('Simulations/delta_asc.dat', dtype=str)[:,0]
asc = np.loadtxt('Simulations/delta_asc.dat')[:,1]
delta = delta.tolist()
asc = asc.tolist()

# %%
# Parameters and Constants:
mass  = 7.0160040 * 1.66053873e-27 / me # a.u
alpha = 200 # a.u
lambd = 1000 * 1e-9 / ao # a.u
ky    = 2*np.pi/lambd
Iy    = 4993 * (1e4 / Eh * to * ao**2)
Vy    = alpha * Iy # a.u
Iy    = Vy/alpha
wy    = np.sqrt( 2 * Vy * ky**2 / mass)       
dho   = np.sqrt(2 / (mass * wy))
print('wy [u.a]: ', wy/to)
print('dho [u.a]: ', dho)
# Out:
# wy [u.a]:  2141065.2804475287
# dho [u.a]:  1737.6709708894564

# %%
print(os.getcwd())
folder_path = "Simulations/ix4993_LiLi/config/"
# Out:
# /Users/tomy/PhD/Ultracold_Atoms_src/Analysis/q1dq3d

# %%
Data = list()
delta_nonreaded = list()
for d in delta:
    try:
        Data.append(np.loadtxt(folder_path + f'Li7Li7_x18000_y18000_z18000_140rm8g2l60m8_80CM8g1L60M16_LiLi_a3Sup_0{d}_Li7Li7_nx6ny6nz6_nx6ny6nz6_ix4993iy4993iz4993_ix4993iy4993iz50/Ag_B1u_vsLiLi3d1d_rm250_CM50_ddb.eva'))
    except:
        delta_nonreaded.append(d)
        continue
print(f'There are a few folders without data, \ndelta={delta_nonreaded} non readed')
# Out:
# There are a few folders without data,
# delta=['.69000', '.69100', '.69200', '.69300', '.69400', '.69500', '.69600', '.69700', '.69800', '.69900', '.70000', '.70100', '.70200', '.70205', '.70210', '.70215', '.70220', '.70225', '.70230', '.70235', '.70240', '.70245', '.70316', '.70556', '.70557', '.70558', '.70559', '.70561', '.70562', '.70563', '.70564', '.70566', '.70567', '.70568', '.70569', '.70571', '.70572', '.70573', '.70574', '.70576', '.70577', '.70578', '.70579', '.70581', '.70582', '.70583', '.70584', '.70586', '.70587', '.70588', '.70589', '.70591', '.70592', '.70593', '.70594', '.70596', '.70597', '.70598', '.70599', '.70601', '.70602', '.70603', '.70604', '.70606', '.70607', '.70608', '.70609', '.70611', '.70612', '.70613', '.70614', '.70616', '.70617', '.70618', '.70619', '.70621', '.70622', '.70623', '.70624', '.70626', '.70627', '.70628', '.70629', '.70631', '.70632', '.70633', '.70634', '.70636', '.70637', '.70638', '.70639', '.70641', '.70642', '.70643', '.70644', '.70646', '.70647', '.70648', '.70649', '.70651', '.70652', '.70653', '.70654', '.70656', '.70657', '.70658', '.70659', '.70661', '.70662', '.70663', '.70664', '.70666', '.70667', '.70668', '.70669', '.70671', '.70672', '.70673', '.70674', '.707666', '.707891', '.7083468', '.708483', '.708822', '.7090032', '.7090948', '.7092404', '.7091583', '.71305', '.71310', '.71315', '.71320', '.71325', '.71330', '.71335', '.71340', '.71345', '.71350', '.71355', '.71360', '.71365', '.71370', '.71375', '.71380', '.71385', '.71390', '.71395', '.71400', '.71405', '.71410', '.71415', '.71420', '.71425', '.71430', '.71435', '.71440', '.71445', '.71450', '.71455', '.71460', '.71465', '.71470', '.71475', '.71480', '.71485', '.71490', '.71495', '.71500', '.71505', '.71510', '.71515', '.71520', '.71525', '.71530', '.71535', '.71540', '.71545', '.71550', '.71555', '.71560', '.71565', '.71570', '.71575', '.71580', '.71585', '.71590', '.71595', '.71600', '.71605', '.71610', '.71615', '.71620', '.71625', '.71630', '.71635', '.71640', '.71645', '.71650', '.71655', '.71660', '.71665', '.71670', '.71675', '.71680', '.71685', '.71690', '.71695', '.71700', '.71705', '.71710', '.71715', '.71720', '.71725', '.71730', '.71735', '.71740', '.71745', '.71750', '.71755', '.71760', '.71765', '.71770', '.71775', '.71780', '.71785', '.71790', '.71795', '.71800', '.71900', '.72000', '.72100', '.72200', '.72300', '.72400', '.72500', '.72600', '.72700', '.72800', '.72900', '.73000', '.73100', '.73200', '.73300', '.73400', '.73500', '.73600', '.73700', '.73800'] non readed

# %%
# Delete from original delta and asc lists the unreaded values:
for dnr in delta_nonreaded:
    idx = delta.index(dnr)
    del delta[idx], asc[idx]
assert len(delta) == len(asc)
print("filtering completed")
x = dho / asc
# Out:
# filtering completed

# %%
dic = transpose_energies(Data)

# %%
least_bound_pos = 2050

# %%
fig, ax = plt.subplots(figsize=(8,6))
for i in range(least_bound_pos, least_bound_pos + 80):
    ax.plot(x, dic['nivel_{}'.format(i)]/wy, 'C0')
ax.plot(x, dic['nivel_2053']/wy, 'C1')
#ax.set_ylim(0, 7)
#ax.set_xlim(-4, 4)
#ax.vlines(x[165], 0, 10, alpha=0.5, linestyles='--')
#ax.vlines(x[130], 0, 10, alpha=0.5, linestyles='--')
#ax.vlines(x[110], 0, 10, alpha=0.5, linestyles='--')
#ax.vlines(x[90], 0, 10, alpha=0.5, linestyles='--')
#ax.vlines(x[50], 0, 10, alpha=0.5, linestyles='--')
#ax.vlines(x[30], 0, 10, alpha=0.5, linestyles='--')
#ax.vlines(x[20], 0, 10, alpha=0.5, linestyles='--')
ax.set_xlabel('$d_{y}/a_s$')
ax.set_ylabel('$E[\hbar \omega_{y}]$')
plt.tight_layout()
#fig.savefig('Results/Figures/Ix4993_LiLi_3d_1d_Easc.png', dpi=200)
plt.show()

# %%
# %matplotlib inline

# %% [markdown]
# ## Resonance x>1

# %%
fig2, ax2 = plt.subplots(figsize=(8,6))
xpol = np.linspace(x[0], x[-1], num=50)
for i in range(least_bound_pos+2, least_bound_pos + 16):
    print(i)
    ax2.plot(x, dic['nivel_{}'.format(i)]/wy, 'b')
ax2.plot(x, dic['nivel_2053'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2054'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2059'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2060'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2061'.format(i)]/wy, 'r')
ax2.vlines(x[150], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[130], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[120], 0, 10, alpha=0.5, linestyles='--')
#ax2.vlines(x[90], 0, 10, alpha=0.5, linestyles='--')
#ax2.vlines(x[50], 0, 10, alpha=0.5, linestyles='--')
#ax2.vlines(x[30], 0, 10, alpha=0.5, linestyles='--')
#ax2.vlines(x[20], 0, 10, alpha=0.5, linestyles='--')
ax2.set_ylim(2.51, 2.545)
ax2.set_xlim(1, 2.50)
ax2.set_xlabel('$d_{y}/a_s$')
ax2.set_ylabel('$E[\hbar \omega_{y}]$')
ax2.legend(['Data'], fontsize=14)
plt.show()
# Out:
# 2052
# 2053
# 2054
# 2055
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063
# 2064
# 2065

# %%
dho/1.45 # entre 7300 y 7400
# Out:
# 1198.3937730272114

# %%
print('''f Eigenstates:
2052: trap (0,0,2)
2053: (0,2,0) ICIR
2054: (2,0,0) ICIR
2055: (0,0,4)
2056: (0,2,2)
2057: (0,0,6) 
2058: (2,0,2) 
2059: (0,4,0) ICIR
2060: (4,0,0) ICIR
2061: (2,2,0) ICIR
''')
# Out:
# f Eigenstates:
# 2052: trap (0,0,2)
# 2053: (0,2,0) ICIR
# 2054: (2,0,0) ICIR
# 2055: (0,0,4)
# 2056: (0,2,2)
# 2057: (0,0,6)
# 2058: (2,0,2)
# 2059: (0,4,0) ICIR
# 2060: (4,0,0) ICIR
# 2061: (2,2,0) ICIR

# %%
print(f'''To find the eigenstates:
x={x[150]}, delta=0{delta[150]}
x={x[140]}, delta=0{delta[140]}
x={x[120]}, delta=0{delta[120]}
x={x[90]}, delta=0{delta[90]}
x={x[50]}, delta=0{delta[50]}
x={x[30]}, delta=0{delta[30]}
x={x[20]}, delta=0{delta[20]}
x={x[10]}, delta=0{delta[10]}
x={x[5]}, delta=0{delta[5]}
''')
# Out:
# To find the eigenstates:
# x=1.0591623503560998, delta=0.71000
# x=1.1594786048334198, delta=0.70950
# x=1.3590395644667697, delta=0.70850
# x=1.655740694128729, delta=0.70700
# x=2.0465192587369625, delta=0.70500
# x=2.239885714434933, delta=0.70400
# x=2.3360716455258417, delta=0.70350
# x=2.431929187165269, delta=0.70300
# x=2.4797355480450016, delta=0.70275

# %%
# %matplotlib inline

# %% [markdown]
# # (2,0,0) (0,2,0)

# %%
fig3, ax3 = plt.subplots(figsize=(8,6))
# nivel 2052:
trap_poly = trap_fit(dic, x, x_lims=(1.1, 1.4), y_lims=(2.51, 2.6) ,levels=(2052, 2054), tol=1.1, wy=wy)/wy
x2052 = np.linspace(1, 1.95, num=50)
ax3.scatter(x2052, np.polyval(trap_poly, x2052), edgecolor='r', facecolor='C1', label='Diabatic', zorder=1)
ax3.plot(x, dic['nivel_2052']/wy, 'C0', label='Adiabatic', zorder=2)

# nivel 2053:
ax3.plot(x, dic['nivel_2053']/wy, 'C0', zorder=1)
f2053 = np.polyfit(x[(x < 1.15) & (x > 1.1)], np.array(dic['nivel_2053'])[(x < 1.15) & (x > 1.1)]/wy, deg=1)
x2053 = np.linspace(1.15, 1.21, num=70)
ax3.scatter(x2053, np.polyval(f2053, x2053), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2054:
ax3.plot(x, dic['nivel_2054']/wy, 'C0', zorder=1)

# Crosses:
##########
ax3.plot(cross_points(trap_poly, f2053), np.polyval(trap_poly, cross_points(trap_poly, f2053)), 'w*', markersize=16, markeredgecolor='k', label='ICIR')

# States:
#########
ax3.annotate(r'$\left|\psi^{(1)} \Phi_{(0,0,0)}\right>$', xy=(1.25, 2.534), xytext=(1.25, 2.536), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,2,0)}\right>$', xy=(1.20, 2.5382), xytext=(1.22, 2.5382), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,0,4)}\right>$', xy=(1.05, 3.355), xytext=(0.74, 3.36), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,0,0)}\right>$', xy=(1.20, 2.5382), xytext=(1.13, 2.5382), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.set_xlabel('$d_{y}/a_{sc}$')
ax3.set_ylabel('$E[\hbar \omega_{y}]$')
ax3.xaxis.set_minor_locator(AutoMinorLocator())
ax3.yaxis.set_minor_locator(AutoMinorLocator())
ax3.set_ylim(2.530, 2.54)
ax3.set_xlim(1.1, 1.4)
#fig3.savefig('Results/Figures/LiLi_1d3d_4993_Easc_Interpolation_200_v2.png', bbox_inches="tight", dpi=200)
# Out:
# 1.9644528921221716e-14

# %%
print(f'''Crosses between (x, E):
* trap-(0,2,0)-(2,0,0): ({cross_points(trap_poly, f2053)}, {np.polyval(trap_poly, cross_points(trap_poly, f2053))})
''')
# Out:
# Crosses between (x, E):
# * trap-(0,2,0)-(2,0,0): (1.1970459539951366, 2.5357712039611853)

# %%
print(f'''ICIR: asc/dy:
* trap-(0,2,0)-(2,0,0): {1/cross_points(trap_poly, f2053)} 
''')
# Out:
# ICIR: asc/dy:
# * trap-(0,2,0)-(2,0,0): 0.8353898166252545

# %% [markdown]
# # $$(4,0,0) (0,4,0)$$

# %%
fig3, ax3 = plt.subplots(figsize=(8,6))
# nivel 2057:
trap_poly = trap_fit(dic, x, x_lims=(1, 2.43), y_lims=(2.51, 2.55) ,levels=(2057, 2061), tol=0.1, wy=wy)/wy

# nivel 2057:
ax3.plot(x, dic['nivel_2057']/wy, 'C0', zorder=1)
x2057 = np.linspace(1.4, 2.5, num=50)
ax3.scatter(x2057, np.polyval(trap_poly, x2057), edgecolor='r', facecolor='C1', label='Diabatic', zorder=1)

# nivel 2058:
ax3.plot(x, dic['nivel_2058']/wy, 'C0', zorder=1)

# nivel 2059:
ax3.plot(x, dic['nivel_2059']/wy, 'C0', zorder=1)
f2059 = np.polyfit(x[(x < 2.04) & (x > 1.98)], np.array(dic['nivel_2059'])[(x < 2.04) & (x > 1.98)]/wy, deg=1)
x2059 = np.linspace(2.05, 2.1, num=100)
ax3.scatter(x2059, np.polyval(f2059, x2059), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2060:
ax3.plot(x, dic['nivel_2060']/wy, 'C0', zorder=1)

# nivel 2061:
ax3.plot(x, dic['nivel_2061']/wy, 'C0', zorder=1)


# nivel 2062:
ax3.plot(x, dic['nivel_2062']/wy, 'C0', zorder=1)


# nivel 2063:
ax3.plot(x, dic['nivel_2063']/wy, 'C0', zorder=1)

# Crosses:
##########
ax3.plot(cross_points(trap_poly, f2059), np.polyval(trap_poly, cross_points(trap_poly, f2059)), 'w*', markersize=16, markeredgecolor='k', label='ICIR')

# States:
#########
ax3.annotate(r'$\left|\psi^{(1)} \Phi_{(0,0,0)}\right>$', xy=(2.16, 2.517), xytext=(2.16, 2.518), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,4,0)}\right>$', xy=(2.073, 2.51655), xytext=(2.10, 2.5165), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,2,0)}\right>$', xy=(2.19, 2.5714), xytext=(2.23, 2.5713), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(4,0,0)}\right>$', xy=(2.073, 2.51655), xytext=(2.005, 2.5165), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.set_xlabel('$d_{y}/a_{sc}$')
ax3.set_ylabel('$E[\hbar \omega_{y}]$')
ax3.xaxis.set_minor_locator(AutoMinorLocator())
ax3.yaxis.set_minor_locator(AutoMinorLocator())
ax3.set_ylim(2.515, 2.520)
ax3.set_xlim(2, 2.3)
#fig3.savefig('Results/Figures/LiLi_1d3d_4993_Easc_Interpolation_400_v2.png', bbox_inches="tight", dpi=200)
# Out:
# 1.00602226151979e-12

# %%
print(f'''Crosses between (x, E):
* trap-(0,4,0)-(4,0,0): ({cross_points(trap_poly, f2059)}, {np.polyval(trap_poly, cross_points(trap_poly, f2059))})
''')
# Out:
# Crosses between (x, E):
# * trap-(0,4,0)-(4,0,0): (2.0744581426072264, 2.51844147956061)

# %%
print(f'''ICIR: asc/dy:
* trap-(0,4,0)-(4,0,0): {1/cross_points(trap_poly, f2059)} 
''')
# Out:
# ICIR: asc/dy:
# * trap-(0,4,0)-(4,0,0): 0.48205359243507184
