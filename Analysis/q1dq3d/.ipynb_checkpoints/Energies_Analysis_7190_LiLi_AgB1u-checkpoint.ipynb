# %%
__author__ = "@Tssp"
__date__   = "02/09/21"
import numpy as np
import matplotlib.pyplot as plt
import os
from utils.atomic_units import ao, vo, e, hbar, me, Eh, to
from decimal import Decimal
from utils.Energies_Analysis_utils import *
from matplotlib.ticker import AutoMinorLocator
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
ref_ticksize = 16
plt.rcParams['xtick.labelsize']=ref_ticksize
plt.rcParams['ytick.labelsize']=ref_ticksize
plt.rcParams['legend.fontsize']=ref_ticksize
plt.rcParams['axes.labelsize']=ref_ticksize * 3/2
plt.rcParams['axes.titlesize']=ref_ticksize * 3/2
aur = (1 + np.sqrt(5)) / 2
aursize = (5*aur, 5)

# %%
delta = np.loadtxt('Simulations/delta_asc_7190.dat', dtype=str)[:,0]
asc = np.loadtxt('Simulations/delta_asc_7190.dat')[:,1]
delta = delta.tolist()
asc = asc.tolist()

# %%
# Parameters and Constants:
mass  = 7.0160040 * 1.66053873e-27 / me # a.u
alpha = 200 # a.u
lambd = 1000 * 1e-9 / ao # a.u
ky    = 2*np.pi/lambd
Iy    = 4993 * (1e4 / Eh * to * ao**2)
Vy    = alpha * Iy # a.u
Iy    = Vy/alpha
wy    = np.sqrt( 2 * Vy * ky**2 / mass)       
dho   = np.sqrt(2 / (mass * wy))
print('wy [u.a]: ', wy/to)
print('dho [u.a]: ', dho)
# Out:
# wy [u.a]:  2141065.2804475287
# dho [u.a]:  1737.6709708894564

# %%
print(os.getcwd())
folder_path = "Simulations/ix7190_LiLi/config/"
# Out:
# /Users/tomy/PhD/Ultracold_Atoms_src/Analysis/q1dq3d

# %%
Data = list()
delta_nonreaded = list()
for d in delta:
    try:
        Data.append(np.loadtxt(folder_path + f'Li7Li7_x18000_y18000_z18000_140rm8g2l60m8_80CM8g1L60M16_LiLi_a3Sup_0{d}_Li7Li7_nx6ny6nz6_nx6ny6nz6_ix7190iy4993iz4993_ix7190iy4993iz50/Ag_B1u_vsLiLi3d1d_rm250_CM50_ddb.eva'))
    except:
        delta_nonreaded.append(d)
        continue
print(f'There are a few folders without data, \ndelta={delta_nonreaded} non readed')
# Out:
# There are a few folders without data,
# ...

# %%
# Delete from original delta and asc lists the unreaded values:
for dnr in delta_nonreaded:
    idx = delta.index(dnr)
    del delta[idx], asc[idx]
assert len(delta) == len(asc)
print("filtering completed")
x = dho / asc
# Out:
# filtering completed

# %%
dic = transpose_energies(Data)

# %%
least_bound_pos = 2050

# %%
fig, ax = plt.subplots(figsize=(8,6))
for i in range(least_bound_pos, least_bound_pos + 80):
    ax.plot(x, dic['nivel_{}'.format(i)]/wy, 'C0')
ax.plot(x, dic['nivel_2063']/wy, 'C1')
ax.set_ylim(0, 7)
#ax.set_xlim(-4, 4)
ax.vlines(x[165], 0, 10, alpha=0.5, linestyles='--')
ax.vlines(x[130], 0, 10, alpha=0.5, linestyles='--')
ax.vlines(x[110], 0, 10, alpha=0.5, linestyles='--')
ax.vlines(x[90], 0, 10, alpha=0.5, linestyles='--')
ax.vlines(x[50], 0, 10, alpha=0.5, linestyles='--')
ax.vlines(x[30], 0, 10, alpha=0.5, linestyles='--')
ax.vlines(x[20], 0, 10, alpha=0.5, linestyles='--')
ax.set_xlabel('$d_{y}/a_s$')
ax.set_ylabel('$E[\hbar \omega_{y}]$')
plt.tight_layout()
#fig.savefig('Results/Figures/Ix7802_LiLi_3d_1d_Easc.png', dpi=200)
plt.show()

# %%
70250 + 5*97
# Out:
# 70735

# %%
delta[-1]
# Out:
# '.71300'

# %%
# %matplotlib inline

# %% [markdown]
# ## Resonance x>1

# %%
fig2, ax2 = plt.subplots(figsize=(8,6))
xpol = np.linspace(x[0], x[-1], num=50)
for i in range(least_bound_pos+2, least_bound_pos + 16):
    print(i)
    ax2.plot(x, dic['nivel_{}'.format(i)]/wy, 'b')
ax2.plot(x, dic['nivel_2053'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2054'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2058'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2061'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2063'.format(i)]/wy, 'r')
ax2.vlines(x[140], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[130], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[110], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[90], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[50], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[30], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[20], 0, 10, alpha=0.5, linestyles='--')
ax2.set_ylim(2.71, 2.745)
ax2.set_xlim(1, 2.50)
ax2.set_xlabel('$d_{y}/a_s$')
ax2.set_ylabel('$E[\hbar \omega_{y}]$')
ax2.legend(['Data'], fontsize=14)
plt.show()
# Out:
# 2052
# 2053
# 2054
# 2055
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063
# 2064
# 2065

# %%
dho/1.45 # entre 7300 y 7400
# Out:
# 1198.3937730272114

# %%
print('''f Eigenstates:
2052: trap (0,0,2)
2053: (0,2,0) ICIR
2054: (2,0,0) ICIR
2055: (0,0,4)
2056: (0,2,2)
2057: (0,0,6)
2058: (0,4,0) ICIR
2059: (2,0,2)
2060: (0,0,8)
2061: (2,2,0) ICIR
2062: (0,2,4) 
2063: (4,0,0) ICIR
''')
# Out:
# f Eigenstates:
# 2052: trap (0,0,2)
# 2053: (0,2,0) ICIR
# 2054: (2,0,0) ICIR
# 2055: (0,0,4)
# 2056: (0,2,2)
# 2057: (0,0,6)
# 2058: (0,4,0) ICIR
# 2059: (2,0,2)
# 2060: (0,0,8)
# 2061: (2,2,0) ICIR
# 2062: (0,2,4)
# 2063: (4,0,0) ICIR

# %%
print(f'''To find the eigenstates:
x={x[140]}, delta=0{delta[140]}
x={x[110]}, delta=0{delta[110]}
x={x[90]}, delta=0{delta[90]}
x={x[50]}, delta=0{delta[50]}
x={x[30]}, delta=0{delta[30]}
x={x[20]}, delta=0{delta[20]}
x={x[10]}, delta=0{delta[10]}
x={x[5]}, delta=0{delta[5]}
''')
# Out:
# To find the eigenstates:
# x=1.436484606512689, delta=0.70811
# x=1.6852387551045638, delta=0.70685
# x=1.8811033087647553, delta=0.70585
# x=2.2687761160924436, delta=0.70385
# x=2.361026102305394, delta=0.70337
# x=2.3917088687611776, delta=0.70321
# x=2.4108685751497787, delta=0.70311
# x=2.4797355480450016, delta=0.70275

# %%
# %matplotlib inline

# %% [markdown]
# # (2,0,0) (0,2,0)

# %%
fig3, ax3 = plt.subplots(figsize=(8,6))
# nivel 2052:
trap_poly = trap_fit(dic, x, x_lims=(1, 2), y_lims=(2.71, 2.745) ,levels=(2052, 2053), tol=3, wy=wy)/wy
x2052 = np.linspace(0.25, 1.95, num=50)
ax3.scatter(x2052, np.polyval(trap_poly, x2052), edgecolor='r', facecolor='C1', label='Diabatic', zorder=1)
ax3.plot(x, dic['nivel_2052']/wy, 'C0', label='Adiabatic', zorder=2)

# nivel 2053:
ax3.plot(x, dic['nivel_2053']/wy, 'C0', zorder=1)
f2053 = np.polyfit(x[(x < 1.1) & (x > 1)], np.array(dic['nivel_2053'])[(x < 1.1) & (x > 1)]/wy, deg=1)
x2053 = np.linspace(1.1, 1.2, num=50)
ax3.scatter(x2053, np.polyval(f2053, x2053), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2054:
ax3.plot(x, dic['nivel_2054']/wy, 'C0', zorder=1)
f2054 = np.polyfit(x[(x < 1.41) & (x > 1.37)], np.array(dic['nivel_2054'])[(x < 1.41) & (x > 1.37)]/wy, deg=1)
x2054 = np.linspace(1.4, 1.5, num=70)
ax3.scatter(x2054, np.polyval(f2054, x2054), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2055:
ax3.plot(x, dic['nivel_2055']/wy, 'C0', zorder=1)
f2055 = np.polyfit(x[(x < 1.45) & (x > 1.4)], np.array(dic['nivel_2055'])[(x < 1.45) & (x > 1.4)]/wy, deg=1)
x2055 = np.linspace(1.4, 1.5, num=70)
ax3.scatter(x2055, np.polyval(f2055, x2055), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2056:
ax3.plot(x, dic['nivel_2056']/wy, 'C0', zorder=1)

# nivel 2057:
ax3.plot(x, dic['nivel_2057']/wy, 'C0', zorder=1)

# Crosses:
##########
ax3.plot(cross_points(trap_poly, f2053), np.polyval(trap_poly, cross_points(trap_poly, f2053)), 'w*', markersize=16, markeredgecolor='k', label='ICIR')
ax3.plot(cross_points(trap_poly, f2054), np.polyval(trap_poly, cross_points(trap_poly, f2054)), 'w*', markersize=16, markeredgecolor='k')
ax3.plot(cross_points(trap_poly, f2055), np.polyval(trap_poly, cross_points(trap_poly, f2055)), 'w*', markersize=16, markeredgecolor='k')

# States:
#########
ax3.annotate(r'$\left|\psi^{(1)} \Phi_{(0,0,0)}\right>$', xy=(1.22, 2.7355), xytext=(1.20, 2.7375), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,2,0)}\right>$', xy=(1.15, 2.7285), xytext=(1.20, 2.7285), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,0,4)}\right>$', xy=(1.05, 3.355), xytext=(0.74, 3.36), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,0,0)}\right>$', xy=(1.40, 2.7375), xytext=(1.29, 2.7375), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.set_xlabel('$d_{y}/a_{sc}$')
ax3.set_ylabel('$E[\hbar \omega_{y}]$')
ax3.xaxis.set_minor_locator(AutoMinorLocator())
ax3.yaxis.set_minor_locator(AutoMinorLocator())
ax3.set_ylim(2.725, 2.745)
ax3.set_xlim(1, 1.45)
#fig3.savefig('Results/Figures/LiLi_1d3d_7190_Easc_Interpolation_200_v2.png', bbox_inches="tight", dpi=200)
# Out:
# 1.834293785968198e-14
# (1.0, 1.45)

# %%
print(f'''Crosses between (x, E):
* trap-(0,2,0): ({cross_points(trap_poly, f2053)}, {np.polyval(trap_poly, cross_points(trap_poly, f2053))})
* trap-(2,0,0): ({cross_points(trap_poly, f2054)}, {np.polyval(trap_poly, cross_points(trap_poly, f2054))})
''')
# Out:
# Crosses between (x, E):
# * trap-(0,2,0): (1.1352808790394673, 2.7382833224267404)
# * trap-(2,0,0): (1.4072994766123867, 2.729682930966466)

# %%
print(f'''ICIR: asc/dy:
* trap-(0,2,0): {1/cross_points(trap_poly, f2053)} 
* trap-(2,0,0): {1/cross_points(trap_poly, f2054)} 
''')
# Out:
# ICIR: asc/dy:
# * trap-(0,2,0): 0.8808392869666535
# * trap-(2,0,0): 0.710580808576134

# %% [markdown]
# # $$(4,0,0) (0,4,0)$$

# %%
fig3, ax3 = plt.subplots(figsize=(8,6))
# nivel 2057:
trap_poly = trap_fit(dic, x, x_lims=(1, 2.43), y_lims=(2.71, 2.73) ,levels=(2057, 2065), tol=3, wy=wy)/wy

# nivel 2057:
ax3.plot(x, dic['nivel_2057']/wy, 'C0', zorder=1)
x2057 = np.linspace(1.4, 2.5, num=50)
ax3.scatter(x2057, np.polyval(trap_poly, x2057), edgecolor='r', facecolor='C1', label='Diabatic', zorder=1)

# nivel 2058:
ax3.plot(x, dic['nivel_2058']/wy, 'C0', zorder=1)
f2058 = np.polyfit(x[(x < 2.04) & (x > 2.0)], np.array(dic['nivel_2058'])[(x < 2.04) & (x > 2.0)]/wy, deg=1)
x2058 = np.linspace(2, 2.05, num=100)
ax3.scatter(x2058, np.polyval(f2058, x2058), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2059:
ax3.plot(x, dic['nivel_2059']/wy, 'C0', zorder=1)

# nivel 2060:
ax3.plot(x, dic['nivel_2060']/wy, 'C0', zorder=1)

# nivel 2061:
ax3.plot(x, dic['nivel_2061']/wy, 'C0', zorder=1)
f2061 = np.polyfit(x[(x < 2.28) & (x > 2.25)], np.array(dic['nivel_2061'])[(x < 2.28) & (x > 2.25)]/wy, deg=1)
x2061 = np.linspace(2.25, 2.3, num=50)
ax3.scatter(x2061, np.polyval(f2061, x2061), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2062:
ax3.plot(x, dic['nivel_2062']/wy, 'C0', zorder=1)

# nivel 2063:
ax3.plot(x, dic['nivel_2063']/wy, 'C0', zorder=1)
f2063 = np.polyfit(x[(x < 2.35) & (x > 2.31)], np.array(dic['nivel_2063'])[(x < 2.35) & (x > 2.31)]/wy, deg=1)
x2063 = np.linspace(2.3, 2.4, num=100)
ax3.scatter(x2063, np.polyval(f2063, x2063), edgecolor='r', facecolor='C1', zorder=2)

# Crosses:
##########
ax3.plot(cross_points(trap_poly, f2058), np.polyval(trap_poly, cross_points(trap_poly, f2058)), 'w*', markersize=16, markeredgecolor='k', label='ICIR')
ax3.plot(cross_points(trap_poly, f2061), np.polyval(trap_poly, cross_points(trap_poly, f2061)), 'w*', markersize=16, markeredgecolor='k')
ax3.plot(cross_points(trap_poly, f2063), np.polyval(trap_poly, cross_points(trap_poly, f2063)), 'w*', markersize=16, markeredgecolor='k')

# States:
#########
#ax3.annotate(r'$\left|\psi^{(1)} \Phi_{(0,0,0)}\right>$', xy=(2.215, 2.7693), xytext=(2.20, 2.771), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,4,0)}\right>$', xy=(2.07, 2.767), xytext=(2.08, 2.7683), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,2,0)}\right>$', xy=(2.30, 2.767), xytext=(2.20, 2.767), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(4,0,0)}\right>$', xy=(2.41, 2.771), xytext=(2.32, 2.771), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.set_xlabel('$d_{y}/a_{sc}$')
ax3.set_ylabel('$E[\hbar \omega_{y}]$')
ax3.xaxis.set_minor_locator(AutoMinorLocator())
ax3.yaxis.set_minor_locator(AutoMinorLocator())
ax3.set_ylim(2.715, 2.724)
ax3.set_xlim(1.9, 2.43)
#fig3.savefig('Results/Figures/LiLi_1d3d_7190_Easc_Interpolation_400_v2.png', bbox_inches="tight", dpi=200)
# Out:
# 7.500398937279655e-15
# (1.9, 2.43)

# %%
print(f'Desde {dho/745} a {dho/730}')
# Out:
# Desde 2.332444256227458 a 2.3803711929992555

# %%
print(f'''Crosses between (x, E):
* trap-(0,4,0): ({cross_points(trap_poly, f2058)}, {np.polyval(trap_poly, cross_points(trap_poly, f2058))})
* trap-(2,2,0): ({cross_points(trap_poly, f2061)}, {np.polyval(trap_poly, cross_points(trap_poly, f2061))})
* trap-(4,0,0): ({cross_points(trap_poly, f2063)}, {np.polyval(trap_poly, cross_points(trap_poly, f2063))})
''')
# Out:
# Crosses between (x, E):
# * trap-(0,4,0): (2.0360188232994854, 2.7212882039394186)
# * trap-(2,2,0): (2.276024264475191, 2.7179544962503654)
# * trap-(4,0,0): (2.346422626289293, 2.716976653585938)

# %%
print(f'''ICIR: asc/dy:
* trap-(0,4,0): {1/cross_points(trap_poly, f2058)} 
* trap-(2,2,0): {1/cross_points(trap_poly, f2061)} 
* trap-(4,0,0): {1/cross_points(trap_poly, f2063)}
''')
# Out:
# ICIR: asc/dy:
# * trap-(0,4,0): 0.49115459472002454
# * trap-(2,2,0): 0.43936262701952405
# * trap-(4,0,0): 0.4261806840745615
