# %%
__author__ = "@Tssp"
__date__   = "14/10/21"
import numpy as np
import matplotlib.pyplot as plt
import os
from utils.atomic_units import ao, vo, e, hbar, me, Eh, to
from decimal import Decimal
from utils.Energies_Analysis_utils import *
from matplotlib.ticker import AutoMinorLocator
from matplotlib.colors import LogNorm, Normalize
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
ref_ticksize = 16
plt.rcParams['xtick.labelsize']=ref_ticksize
plt.rcParams['ytick.labelsize']=ref_ticksize
plt.rcParams['legend.fontsize']=ref_ticksize
plt.rcParams['axes.labelsize']=ref_ticksize * 3/2
plt.rcParams['axes.titlesize']=ref_ticksize * 3/2
aur = (1 + np.sqrt(5)) / 2
aursize = (5*aur, 5)

# %%
def plot_wf(path, fig, ax):
    Data = np.loadtxt(path)
    x = Data[:,0]
    y = Data[:,1]
    wf = Data[:,2]/np.sum(Data[:,2])
    global cm
    cm = ax.tricontourf(x, y, wf, cmap='seismic', levels=100)
    #ax.set_xlim(-5000, 5000)
    #ax.set_ylim(-5000, 5000)
    return fig

# %%
path = 'Simulations/plots/Li7Li7_x18000_y18000_z18000_140rm8g2l60m8_80CM8g1L60M16_LiLi_a3Sup_0.'
path_end = '_Li7Li7_nx6ny6nz6_nx6ny6nz6_ix4993iy4993iz4993_ix4993iy4993iz50Ag_B1u_vsLiLi3d1d_rm250_CM50_dd_452agCM4Ag_LEV'

# %% [markdown]
# # Y axis

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,6))
plot_wf(path+'70900'+path_end+'2055_y.dat', fig, ax)
cbaxes = fig.add_axes([1.03, 0.1, 0.03, 0.8]) 
cbar = fig.colorbar(cm, ax=fig, cax=cbaxes)
cbar.ax.set_ylabel(r'$|\Psi(y_1, y_2)|^2$', labelpad=10)
ax.set_xlim(-4000, 4000)
ax.set_ylim(-4000, 4000)
ax.set_xlabel(r'$y_1$[a.u]')
ax.set_ylabel(r'$y_2$[a.u]')
# Out:
# Text(0, 0.5, '$y_2$[a.u]')

# %%
fig = plt.subplots(nrows=1, ncols=1, figsize=(12,6), facecolor="white")
# 71000
ax = plt.subplot(2, 3, 1)
plot_wf(f'{path}71000{path_end}{2053}_y.dat', fig, ax)
ax.set_title(str(2053))
ax.set_xlim(-4000, 4000)
ax.set_ylim(-4000, 4000)
ax.set_ylabel(r'$y_2$[a.u]')
ax = plt.subplot(2, 3, 2)
plot_wf(f'{path}71000{path_end}{2054}_y.dat', fig, ax)
ax.set_title(str(2054))
ax.set_xlim(-4000, 4000)
ax.set_ylim(-4000, 4000)
ax = plt.subplot(2, 3, 3)
plot_wf(f'{path}71000{path_end}{2055}_y.dat', fig, ax)
ax.set_title(str(2055))
ax.set_xlim(-4000, 4000)
ax.set_ylim(-4000, 4000)

# 70900
ax = plt.subplot(2, 3, 4)
plot_wf(f'{path}70900{path_end}{2053}_y.dat', fig, ax)
ax.set_xlim(-4000, 4000)
ax.set_ylim(-4000, 4000)
ax.set_xlabel(r'$y_1$[a.u]')
ax.set_ylabel(r'$y_2$[a.u]')
ax = plt.subplot(2, 3, 5)
plot_wf(f'{path}70900{path_end}{2054}_y.dat', fig, ax)
ax.set_xlim(-4000, 4000)
ax.set_ylim(-4000, 4000)
ax.set_xlabel(r'$y_1$[a.u]')
ax = plt.subplot(2, 3, 6)
plot_wf(f'{path}70900{path_end}{2055}_y.dat', fig, ax)
ax.set_xlim(-4000, 4000)
ax.set_ylim(-4000, 4000)
ax.set_xlabel(r'$y_1$[a.u]')

cbaxes = fig[0].add_axes([0.1, -0.13, 0.85, 0.05]) 
cbar = fig[0].colorbar(cm, ax=fig[1], cax=cbaxes, orientation='horizontal')
cbar.ax.set_ylabel(r'$|\Psi(y_1, y_2)|^2$', labelpad=10, rotation=0)
cbar.ax.yaxis.set_label_coords(0.5, 1.2)
plt.tight_layout()
#fig[0].savefig('WF_200Resonance.png', dpi=300, bbox_inches="tight")
# Out:
# <ipython-input-5-af17637ca85f>:42: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # X axis

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,6))
plot_wf(path+'70950'+path_end+'2053_x.dat', fig, ax)
cbaxes = fig.add_axes([1.03, 0.1, 0.03, 0.8]) 
fig.colorbar(cm, ax=fig, cax=cbaxes)
ax.set_xlim(-5000, 5000)
ax.set_ylim(-5000, 5000)
ax.set_xlabel(r'$x_1$')
ax.set_ylabel(r'$x_2$')
# Out:
# Text(0, 0.5, '$x_2$')

# %%
fig = plt.subplots(nrows=1, ncols=1, figsize=(12,6), facecolor="white")
# 71000
ax = plt.subplot(2, 3, 1)
plot_wf(f'{path}71000{path_end}{2053}_x.dat', fig, ax)
ax.set_title(str(2053))
ax.set_xlim(-5000, 5000)
ax.set_ylim(-5000, 5000)
ax.set_ylabel(r'$x_2$')
ax = plt.subplot(2, 3, 2)
plot_wf(f'{path}71000{path_end}{2054}_x.dat', fig, ax)
ax.set_title(str(2054))
ax.set_xlim(-5000, 5000)
ax.set_ylim(-5000, 5000)
ax = plt.subplot(2, 3, 3)
plot_wf(f'{path}71000{path_end}{2055}_x.dat', fig, ax)
ax.set_title(str(2055))
ax.set_xlim(-5000, 5000)
ax.set_ylim(-5000, 5000)

# 70900
ax = plt.subplot(2, 3, 4)
plot_wf(f'{path}70900{path_end}{2054}_x.dat', fig, ax)
ax.set_xlim(-5000, 5000)
ax.set_ylim(-5000, 5000)
ax.set_xlabel(r'$x_1$')
ax.set_ylabel(r'$x_2$')
ax = plt.subplot(2, 3, 5)
plot_wf(f'{path}70900{path_end}{2054}_x.dat', fig, ax)
ax.set_xlim(-5000, 5000)
ax.set_ylim(-5000, 5000)
ax.set_xlabel(r'$x_1$')
ax = plt.subplot(2, 3, 6)
plot_wf(f'{path}70900{path_end}{2055}_x.dat', fig, ax)
ax.set_xlim(-5000, 5000)
ax.set_ylim(-5000, 5000)
ax.set_xlabel(r'$x_1$')

cbaxes = fig[0].add_axes([0.1, -0.13, 0.85, 0.05]) 
cbar = fig[0].colorbar(cm, ax=fig[1], cax=cbaxes, orientation='horizontal')
cbar.ax.set_ylabel(r'$|\Psi(y_1, y_2)|^2$', labelpad=10, rotation=0)
cbar.ax.yaxis.set_label_coords(0.5, 1.2)
plt.tight_layout()
#fig[0].savefig('WF_200Resonance.png', dpi=300, bbox_inches="tight")
# Out:
# <ipython-input-19-32cd502453b5>:42: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
