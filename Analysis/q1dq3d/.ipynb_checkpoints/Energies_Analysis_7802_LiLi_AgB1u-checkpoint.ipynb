# %%
__author__ = "@Tssp"
__date__   = "26/07/21"
import numpy as np
import matplotlib.pyplot as plt
import os
from utils.atomic_units import ao, vo, e, hbar, me, Eh, to
from decimal import Decimal
from utils.Energies_Analysis_utils import *
from matplotlib.ticker import AutoMinorLocator
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
ref_ticksize = 16
plt.rcParams['xtick.labelsize']=ref_ticksize
plt.rcParams['ytick.labelsize']=ref_ticksize
plt.rcParams['legend.fontsize']=ref_ticksize
plt.rcParams['axes.labelsize']=ref_ticksize * 3/2
plt.rcParams['axes.titlesize']=ref_ticksize * 3/2
aur = (1 + np.sqrt(5)) / 2
aursize = (5*aur, 5)

# %%
delta = np.loadtxt('Simulations/delta_asc.dat', dtype=str)[:,0]
asc = np.loadtxt('Simulations/delta_asc.dat')[:,1]
delta = delta.tolist()
asc = asc.tolist()

# %%
# Parameters and Constants:
mass  = 7.0160040 * 1.66053873e-27 / me # a.u
alpha = 200 # a.u
lambd = 1000 * 1e-9 / ao # a.u
ky    = 2*np.pi/lambd
Iy    = 4993 * (1e4 / Eh * to * ao**2)
Vy    = alpha * Iy # a.u
Iy    = Vy/alpha
wy    = np.sqrt( 2 * Vy * ky**2 / mass)       
dho   = np.sqrt(2 / (mass * wy))
print('wy [u.a]: ', wy/to)
print('dho [u.a]: ', dho)
# Out:
# wy [u.a]:  2141065.2804475287
# dho [u.a]:  1737.6709708894564

# %%
print(os.getcwd())
folder_path = "Simulations/ix7802_LiLi/config/"
# Out:
# /Users/tomy/PhD/Ultracold_Atoms_src/Analysis/q1dq3d

# %%
Data = list()
delta_nonreaded = list()
for d in delta:
    try:
        Data.append(np.loadtxt(folder_path + f'Li7Li7_x18000_y18000_z18000_140rm8g2l60m8_80CM8g1L60M16_LiLi_a3Sup_0{d}_Li7Li7_nx6ny6nz6_nx6ny6nz6_ix7802iy4993iz4993_ix7802iy4993iz50/Ag_B1u_vsLiLi3d1d_rm250_CM50_ddb.eva'))
    except:
        delta_nonreaded.append(d)
        continue
print(f'There are a few folders without data, \ndelta={delta_nonreaded} non readed')
# Out:
# There are a few folders without data,
# delta=['.69000', '.69100', '.69200', '.69300', '.69400', '.69500', '.69600', '.69700', '.69800', '.69900', '.70000', '.70100', '.70200', '.70205', '.70210', '.70215', '.70220', '.70225', '.70230', '.70235', '.70240', '.70245', '.70300', '.70400', '.70556', '.70557', '.70558', '.70559', '.70561', '.70562', '.70563', '.70564', '.70566', '.70567', '.70568', '.70569', '.70571', '.70572', '.70573', '.70574', '.70576', '.70577', '.70578', '.70579', '.70581', '.70582', '.70583', '.70584', '.70586', '.70587', '.70588', '.70589', '.70591', '.70592', '.70593', '.70594', '.70596', '.70597', '.70598', '.70599', '.70601', '.70602', '.70603', '.70604', '.70606', '.70607', '.70608', '.70609', '.70611', '.70612', '.70613', '.70614', '.70616', '.70617', '.70618', '.70619', '.70621', '.70622', '.70623', '.70624', '.70626', '.70627', '.70628', '.70629', '.70631', '.70632', '.70633', '.70634', '.70636', '.70637', '.70638', '.70639', '.70641', '.70642', '.70643', '.70644', '.70646', '.70647', '.70648', '.70649', '.70651', '.70652', '.70653', '.70654', '.70656', '.70657', '.70658', '.70659', '.70661', '.70662', '.70663', '.70664', '.70666', '.70667', '.70668', '.70669', '.70671', '.70672', '.70673', '.70674', '.707666', '.707891', '.7081066', '.7083468', '.708483', '.708822', '.7090032', '.7090948', '.7092404', '.7091583', '.71145', '.71150', '.71155', '.71415', '.71420', '.71425', '.71430', '.71435', '.71440', '.71445', '.71450', '.71455', '.71460', '.71465', '.71470', '.71475', '.71480', '.71485', '.71490', '.71495', '.71500', '.71505', '.71510', '.71515', '.71520', '.71525', '.71530', '.71535', '.71540', '.71545', '.71550', '.71555', '.71560', '.71565', '.71575', '.71580', '.71585', '.71590', '.71595', '.71600', '.71605', '.71610', '.71615', '.71620', '.71625', '.71630', '.71635', '.71640', '.71645', '.71650', '.71655', '.71660', '.71665', '.71670', '.71675', '.71680', '.71685', '.71690', '.71695', '.71700', '.71705', '.71710', '.71715', '.71720', '.71725', '.71730', '.71735', '.71740', '.71745', '.71750', '.71755', '.71760', '.71765', '.71770', '.71775', '.71780', '.71785', '.71790', '.71795', '.71800', '.71900', '.72000', '.72100', '.72200', '.72300', '.72400', '.72500', '.72600', '.72700', '.72800', '.72900', '.73000', '.73100', '.73200', '.73300', '.73400', '.73500', '.73600', '.73700', '.73800'] non readed

# %%
# Delete from original delta and asc lists the unreaded values:
for dnr in delta_nonreaded:
    idx = delta.index(dnr)
    del delta[idx], asc[idx]
assert len(delta) == len(asc)
print("filtering completed")
x = dho / asc
# Out:
# filtering completed

# %%
dic = transpose_energies(Data)

# %%
least_bound_pos = 2050

# %%
fig, ax = plt.subplots(figsize=(8,6))
for i in range(least_bound_pos, least_bound_pos + 80):
    ax.plot(x, dic['nivel_{}'.format(i)]/wy, 'C0')
ax.plot(x, dic['nivel_2052']/wy, 'C1')
ax.set_ylim(0, 7)
#ax.set_xlim(-4, 4)
ax.set_xlabel('$d_{y}/a_s$')
ax.set_ylabel('$E[\hbar \omega_{y}]$')
plt.tight_layout()
#fig.savefig('Results/Figures/Ix7802_LiLi_3d_1d_Easc.png', dpi=200)
plt.show()

# %%
# %matplotlib inline

# %% [markdown]
# ## Resonance x>1

# %%
fig2, ax2 = plt.subplots(figsize=(8,6))
xpol = np.linspace(x[0], x[-1], num=50)
for i in range(least_bound_pos+2, least_bound_pos + 16):
    print(i)
    ax2.plot(x, dic['nivel_{}'.format(i)]/wy, 'b')
ax2.plot(x, dic['nivel_2053'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2055'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2058'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2062'.format(i)]/wy, 'r')
ax2.plot(x, dic['nivel_2063'.format(i)]/wy, 'r')
ax2.vlines(x[165], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[135], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[120], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[90], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[50], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[30], 0, 10, alpha=0.5, linestyles='--')
ax2.vlines(x[20], 0, 10, alpha=0.5, linestyles='--')
ax2.set_ylim(2.765, 2.795)
ax2.set_xlim(1, 2.50)
ax2.set_xlabel('$d_{y}/a_s$')
ax2.set_ylabel('$E[\hbar \omega_{y}]$')
ax2.legend(['Data'], fontsize=14)
plt.show()
# Out:
# 2052
# 2053
# 2054
# 2055
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063
# 2064
# 2065

# %%
dho/2.55 # entre 7300 y 7400
# Out:
# 681.4395964272378

# %%
print('''f Eigenstates:
2052: trap (0,0,2)
2053: (0,2,0) ICIR
2054: (0,0,4)
2055: (2,0,0) ICIR
2056: (0,2,2)
2057: (0,0,6)
2058: (0,4,0) ICIR
2059: (2,0,2)
2060: (0,0,8)
2061: (0,2,4)
2062: (2,2,0) ICIR
2063: (4,0,0) ICIR
''')
# Out:
# f Eigenstates:
# 2052: trap (0,0,2)
# 2053: (0,2,0) ICIR
# 2054: (0,0,4)
# 2055: (2,0,0) ICIR
# 2056: (0,2,2)
# 2057: (0,0,6)
# 2058: (0,4,0) ICIR
# 2059: (2,0,2)
# 2060: (0,0,8)
# 2061: (0,2,4)
# 2062: (2,2,0) ICIR
# 2063: (4,0,0) ICIR

# %%
print(f'''To find the eigenstates:
x={x[135]}, delta=0{delta[135]}
x={x[120]}, delta=0{delta[120]}
x={x[90]}, delta=0{delta[90]}
x={x[50]}, delta=0{delta[50]}
x={x[30]}, delta=0{delta[30]}
x={x[20]}, delta=0{delta[20]}
''')
# Out:
# To find the eigenstates:
# x=1.1895035440959951, delta=0.70935
# x=1.3391473297896508, delta=0.70860
# x=1.6360580594956653, delta=0.70710
# x=2.0271091077285637, delta=0.70510
# x=2.2206089225551335, delta=0.70410
# x=2.3264678533342007, delta=0.70355

# %%
# %matplotlib inline

# %% [markdown]
# # (2,0,0) (0,2,0)

# %%
fig3, ax3 = plt.subplots(figsize=(8,6))
# nivel 2052:
trap_poly = trap_fit(dic, x, x_lims=(1, 2), y_lims=(2.765, 2.795) ,levels=(2052, 2060), tol=10, wy=wy)/wy
x2052 = np.linspace(0.25, 1.95, num=20)
ax3.scatter(x2052, np.polyval(trap_poly, x2052), edgecolor='r', facecolor='C1', label='Diabatic', zorder=1)
ax3.plot(x, dic['nivel_2052']/wy, 'C0', label='Adiabatic', zorder=2)

# nivel 2053:
ax3.plot(x, dic['nivel_2053']/wy, 'C0', zorder=1)
f2053 = np.polyfit(x[(x < 1.1) & (x > 1)], np.array(dic['nivel_2053'])[(x < 1.1) & (x > 1)]/wy, deg=1)
x2053 = np.linspace(1, 1.2, num=50)
ax3.scatter(x2053, np.polyval(f2053, x2053), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2054:
ax3.plot(x, dic['nivel_2054']/wy, 'C0', zorder=1)
f2054 = np.polyfit(x[(x < 1.45) & (x > 1.40)], np.array(dic['nivel_2055'])[(x < 1.45) & (x > 1.40)]/wy, deg=1)
x2054 = np.linspace(1.4, 1.5, num=50)
ax3.scatter(x2054, np.polyval(f2054, x2054), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2055:
ax3.plot(x, dic['nivel_2055']/wy, 'C0', zorder=1)
f2055 = np.polyfit(x[(x < 1.9) & (x > 1.8)], np.array(dic['nivel_2056'])[(x < 1.9) & (x > 1.8)]/wy, deg=1)
x2055 = np.linspace(1.8, 1.95, num=50)
ax3.scatter(x2055, np.polyval(f2055, x2055), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2056:
ax3.plot(x, dic['nivel_2056']/wy, 'C0', zorder=1)

# nivel 2057:
ax3.plot(x, dic['nivel_2057']/wy, 'C0', zorder=1)

# Crosses:
##########
ax3.plot(cross_points(trap_poly, f2053), np.polyval(trap_poly, cross_points(trap_poly, f2053)), 'w*', markersize=16, markeredgecolor='k', label='ICIR')
ax3.plot(cross_points(trap_poly, f2054), np.polyval(trap_poly, cross_points(trap_poly, f2054)), 'w*', markersize=16, markeredgecolor='k')

# States:
#########
ax3.annotate(r'$\left|\psi^{(1)} \Phi_{(0,0,0)}\right>$', xy=(1.68, 2.777), xytext=(1.6, 2.781), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,2,0)}\right>$', xy=(1.15, 2.779), xytext=(1.2, 2.779), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,0,4)}\right>$', xy=(1.05, 3.355), xytext=(0.74, 3.36), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,0,0)}\right>$', xy=(1.45, 2.791), xytext=(1.2, 2.791), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.set_xlabel('$d_{y}/a_{sc}$')
ax3.set_ylabel('$E[\hbar \omega_{y}]$')
ax3.xaxis.set_minor_locator(AutoMinorLocator())
ax3.yaxis.set_minor_locator(AutoMinorLocator())
ax3.set_ylim(2.77, 2.795)
ax3.set_xlim(1, 2.01)
#fig3.savefig('Results/Figures/LiLi_1d3d_7802_Easc_Interpolation_200_v2.png', bbox_inches="tight", dpi=200)
# Out:
# 1.8211347157490914e-14
# (1.0, 2.01)

# %%
print(f'''Crosses between (x, E):
* trap-(0,2,0): ({cross_points(trap_poly, f2053)}, {np.polyval(trap_poly, cross_points(trap_poly, f2053))})
* trap-(2,0,0): ({cross_points(trap_poly, f2055)}, {np.polyval(trap_poly, cross_points(trap_poly, f2055))})
''')
# Out:
# Crosses between (x, E):
# * trap-(0,2,0): (1.1196681777310291, 2.7878933522087355)
# * trap-(2,0,0): (1.8577790716990752, 2.7746568035349948)

# %%
print(f'''ICIR: asc/dy:
* trap-(0,2,0): {1/cross_points(trap_poly, f2053)} 
* trap-(2,0,0): {1/cross_points(trap_poly, f2055)} 
''')
# Out:
# ICIR: asc/dy:
# * trap-(0,2,0): 0.8931217479329164
# * trap-(2,0,0): 0.5382771370577594

# %% [markdown]
# # $$(4,0,0) (0,4,0)$$

# %%
fig3, ax3 = plt.subplots(figsize=(8,6))
# nivel 2056:
trap_poly = trap_fit(dic, x, x_lims=(1.95, 2.5), y_lims=(2.745, 2.795) ,levels=(2056, 2067), tol=0.3, wy=wy)/wy

# nivel 2057:
ax3.plot(x, dic['nivel_2057']/wy, 'C0', zorder=1)
x2057 = np.linspace(1.95, 2.5, num=20)
ax3.scatter(x2057, np.polyval(trap_poly, x2057), edgecolor='r', facecolor='C1', label='Diabatic', zorder=1)
ax3.plot(x, dic['nivel_2057']/wy, 'C0', label='Adiabatic', zorder=2)

# nivel 2058:
ax3.plot(x, dic['nivel_2058']/wy, 'C0', zorder=1)
f2058 = np.polyfit(x[(x < 2.20) & (x > 2.05)], np.array(dic['nivel_2058'])[(x < 2.20) & (x > 2.05)]/wy, deg=1)
x2058 = np.linspace(2.05, 2.08, num=50)
ax3.scatter(x2058, np.polyval(f2058, x2058), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2059:
ax3.plot(x, dic['nivel_2059']/wy, 'C0', zorder=1)

# nivel 2060:
ax3.plot(x, dic['nivel_2060']/wy, 'C0', zorder=1)

# nivel 2061:
ax3.plot(x, dic['nivel_2061']/wy, 'C0', zorder=1)

# nivel 2062:
ax3.plot(x, dic['nivel_2062']/wy, 'C0', zorder=1)
f2062 = np.polyfit(x[(x < 2.31) & (x > 2.28)], np.array(dic['nivel_2062'])[(x < 2.31) & (x > 2.28)]/wy, deg=1)
x2062 = np.linspace(2.3, 2.35, num=50)
ax3.scatter(x2062, np.polyval(f2062, x2062), edgecolor='r', facecolor='C1', zorder=2)

# nivel 2063:
ax3.plot(x, dic['nivel_2063']/wy, 'C0', zorder=1)
f2063 = np.polyfit(x[(x < 2.42) & (x > 2.36)], np.array(dic['nivel_2063'])[(x < 2.42) & (x > 2.36)]/wy, deg=1)
x2063 = np.linspace(2.35, 2.42, num=150)
ax3.scatter(x2063, np.polyval(f2063, x2063), edgecolor='r', facecolor='C1', zorder=2)

# Crosses:
##########
ax3.plot(cross_points(trap_poly, f2058), np.polyval(trap_poly, cross_points(trap_poly, f2058)), 'w*', markersize=16, markeredgecolor='k', label='ICIR')
ax3.plot(cross_points(trap_poly, f2062), np.polyval(trap_poly, cross_points(trap_poly, f2062)), 'w*', markersize=16, markeredgecolor='k')
ax3.plot(cross_points(trap_poly, f2063), np.polyval(trap_poly, cross_points(trap_poly, f2063)), 'w*', markersize=16, markeredgecolor='k')

# States:
#########
ax3.annotate(r'$\left|\psi^{(1)} \Phi_{(0,0,0)}\right>$', xy=(2.215, 2.7693), xytext=(2.20, 2.771), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,4,0)}\right>$', xy=(2.07, 2.767), xytext=(2.08, 2.7683), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,2,0)}\right>$', xy=(2.30, 2.767), xytext=(2.20, 2.767), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(4,0,0)}\right>$', xy=(2.41, 2.771), xytext=(2.32, 2.771), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.set_xlabel('$d_{y}/a_{sc}$')
ax3.set_ylabel('$E[\hbar \omega_{y}]$')
ax3.xaxis.set_minor_locator(AutoMinorLocator())
ax3.yaxis.set_minor_locator(AutoMinorLocator())
ax3.set_ylim(2.765, 2.772)
ax3.set_xlim(2.04, 2.45)
fig3.savefig('Results/Figures/LiLi_1d3d_7802_Easc_Interpolation_400_v2.png', bbox_inches="tight", dpi=200)
# Out:
# 7.706835343925911e-13

# %%
print(f'''Crosses between (x, E):
* trap-(0,4,0): ({cross_points(trap_poly, f2058)}, {np.polyval(trap_poly, cross_points(trap_poly, f2058))})
* trap-(2,2,0): ({cross_points(trap_poly, f2062)}, {np.polyval(trap_poly, cross_points(trap_poly, f2062))})
* trap-(4,0,0): ({cross_points(trap_poly, f2063)}, {np.polyval(trap_poly, cross_points(trap_poly, f2063))})
''')
# Out:
# Crosses between (x, E):
# * trap-(0,4,0): (2.0690606056854612, 2.7712327223066584)
# * trap-(2,2,0): (2.3044189473924304, 2.7680536314390425)
# * trap-(4,0,0): (2.409891266981629, 2.7666289694297825)

# %%
print(f'''ICIR: asc/dy:
* trap-(0,4,0): {1/cross_points(trap_poly, f2058)} 
* trap-(2,2,0): {1/cross_points(trap_poly, f2062)} 
* trap-(4,0,0): {1/cross_points(trap_poly, f2063)}
''')
# Out:
# ICIR: asc/dy:
# * trap-(0,4,0): 0.48331112063714005
# * trap-(2,2,0): 0.43394887076915933
# * trap-(4,0,0): 0.41495648110816746
