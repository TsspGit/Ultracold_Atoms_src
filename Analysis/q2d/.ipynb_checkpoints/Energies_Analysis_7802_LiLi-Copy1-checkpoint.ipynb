# %%
__author__ = "@Tssp"
__date__   = "26/07/21"
import numpy as np
import matplotlib.pyplot as plt
import os
from utils.atomic_units import ao, vo, e, hbar, me, Eh, to
from decimal import Decimal
from utils.Energies_Analysis_utils import *
from matplotlib.ticker import AutoMinorLocator
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
ref_ticksize = 16
plt.rcParams['xtick.labelsize']=ref_ticksize
plt.rcParams['ytick.labelsize']=ref_ticksize
plt.rcParams['legend.fontsize']=ref_ticksize
plt.rcParams['axes.labelsize']=ref_ticksize * 3/2
plt.rcParams['axes.titlesize']=ref_ticksize * 3/2
aur = (1 + np.sqrt(5)) / 2
aursize = (5*aur, 5)

# %%
delta = np.loadtxt('Simulations/delta_asc.dat', dtype=str)[:,0]
asc = np.loadtxt('Simulations/delta_asc.dat')[:,1]
delta = delta.tolist()
asc = asc.tolist()

# %%
# Parameters and Constants:
mass  = 7.0160040 * 1.66053873e-27 / me # a.u
alpha = 200 # a.u
lambd = 1000 * 1e-9 / ao # a.u
ky    = 2*np.pi/lambd
Iy    = 4993 * (1e4 / Eh * to * ao**2)
Vy    = alpha * Iy # a.u
Iy    = Vy/alpha
wy    = np.sqrt( 2 * Vy * ky**2 / mass)       
dho   = np.sqrt(2 / (mass * wy))
print('wy [u.a]: ', wy/to)
print('dho [u.a]: ', dho)
# Out:
# wy [u.a]:  2141065.2804475287
# dho [u.a]:  1737.6709708894564

# %%
print(os.getcwd())
folder_path = "Simulations/ix7802_LiLi/config/"
# Out:
# /Users/tomy/PhD/Ultracold_Atoms_src/Analysis/q1dq3d

# %%
Data = list()
delta_nonreaded = list()
for d in delta:
    try:
        Data.append(np.loadtxt(folder_path + f'Li7Li7_x18000_y18000_z18000_140rm8g2l60m8_80CM8g1L60M16_LiLi_a3Sup_0{d}_Li7Li7_nx6ny6nz6_nx6ny6nz6_ix7802iy4993iz4993_ix7802iy4993iz50/Ag_B1u_vsLiLi3d1d_rm250_CM50_ddb.eva'))
    except:
        delta_nonreaded.append(d)
        continue
print(f'There are a few folders without data, \ndelta={delta_nonreaded} non readed')
# Out:
# There are a few folders without data,
# delta=['.69000', '.69100', '.69200', '.69300', '.69400', '.69500', '.69600', '.69700', '.69800', '.69900', '.70000', '.70100', '.70200', '.70300', '.70400', '.70556', '.70557', '.70558', '.70559', '.70561', '.70562', '.70563', '.70564', '.70566', '.70567', '.70568', '.70569', '.70571', '.70572', '.70573', '.70574', '.70576', '.70577', '.70578', '.70579', '.70581', '.70582', '.70583', '.70584', '.70586', '.70587', '.70588', '.70589', '.70591', '.70592', '.70593', '.70594', '.70596', '.70597', '.70598', '.70599', '.70601', '.70602', '.70603', '.70604', '.70606', '.70607', '.70608', '.70609', '.70611', '.70612', '.70613', '.70614', '.70616', '.70617', '.70618', '.70619', '.70621', '.70622', '.70623', '.70624', '.70626', '.70627', '.70628', '.70629', '.70631', '.70632', '.70633', '.70634', '.70636', '.70637', '.70638', '.70639', '.70641', '.70642', '.70643', '.70644', '.70646', '.70647', '.70648', '.70649', '.70651', '.70652', '.70653', '.70654', '.70656', '.70657', '.70658', '.70659', '.70661', '.70662', '.70663', '.70664', '.70666', '.70667', '.70668', '.70669', '.70671', '.70672', '.70673', '.70674', '.707666', '.707891', '.7081066', '.7083468', '.708483', '.708822', '.7090032', '.7090948', '.7092404', '.7091583', '.71145', '.71150', '.71155', '.71415', '.71420', '.71425', '.71430', '.71435', '.71440', '.71445', '.71450', '.71455', '.71460', '.71465', '.71470', '.71475', '.71480', '.71485', '.71490', '.71495', '.71500', '.71505', '.71510', '.71515', '.71520', '.71525', '.71530', '.71535', '.71540', '.71545', '.71550', '.71555', '.71560', '.71565', '.71575', '.71580', '.71585', '.71590', '.71595', '.71600', '.71605', '.71610', '.71615', '.71620', '.71625', '.71630', '.71635', '.71640', '.71645', '.71650', '.71655', '.71660', '.71665', '.71670', '.71675', '.71680', '.71685', '.71690', '.71695', '.71700', '.71705', '.71710', '.71715', '.71720', '.71725', '.71730', '.71735', '.71740', '.71745', '.71750', '.71755', '.71760', '.71765', '.71770', '.71775', '.71780', '.71785', '.71790', '.71795', '.71800', '.71900', '.72000', '.72100', '.72200', '.72300', '.72400', '.72500', '.72600', '.72700', '.72800', '.72900', '.73000', '.73100', '.73200', '.73300', '.73400', '.73500', '.73600', '.73700', '.73800'] non readed

# %%
# Delete from original delta and asc lists the unreaded values:
for dnr in delta_nonreaded:
    idx = delta.index(dnr)
    del delta[idx], asc[idx]
assert len(delta) == len(asc)
print("filtering completed")
x = dho / asc
# Out:
# filtering completed

# %%
dic = transpose_energies(Data)

# %%
least_bound_pos = 2050

# %%
fig, ax = plt.subplots(figsize=(8,6))
for i in range(least_bound_pos, least_bound_pos + 80):
    ax.plot(x, dic['nivel_{}'.format(i)]/wy, 'C0')
ax.plot(x, dic['nivel_2050']/wy, 'C1')
ax.set_ylim(0, 7)
#ax.set_xlim(-4, 4)
ax.set_xlabel('$d_{y}/a_s$')
ax.set_ylabel('$E[\hbar \omega_{y}]$')
plt.tight_layout()
#fig.savefig('Results/Figures/Ix7802_LiLi_3d_1d_Easc.png', dpi=200)
plt.show()

# %%
# %matplotlib inline

# %% [markdown]
# ## Resonance x>1

# %%
fig2, ax2 = plt.subplots(figsize=(8,6))
xpol = np.linspace(x[0], x[-1], num=50)
for i in range(least_bound_pos+2, least_bound_pos + 14):
    print(i)
    ax2.plot(x, dic['nivel_{}'.format(i)]/wy, 'b')
#ax2.vlines(x[220], 0, 10, alpha=0.5, linestyles='--')
#ax2.vlines(x[177], 0, 10, alpha=0.5, linestyles='--')
#ax2.vlines(x[150], 0, 10, alpha=0.5, linestyles='--')
#ax2.vlines(x[100], 0, 10, alpha=0.5, linestyles='--')
#ax2.vlines(x[60], 0, 10, alpha=0.5, linestyles='--')
#ax2.vlines(x[45], 0, 10, alpha=0.5, linestyles='--')
ax2.set_ylim(2.9, 3.15)
ax2.set_xlim(0.7, 2.28)
ax2.set_xlabel('$d_{y}/a_s$')
ax2.set_ylabel('$E[\hbar \omega_{y}]$')
ax2.legend(['Data'], fontsize=14)
plt.show()
# Out:
# 2052
# 2053
# 2054
# 2055
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063

# %%
dho/2.3 # entre 7300 y 7400
# Out:
# 755.5091177780246

# %%
print('''f Eigenstates:
1002: trap
1003: (0,2,0) ICIR
1004: (0,0,4) 
1005: (2,0,0) ICIR
1006: (0,0,6)
1007: (0,2,2)
1008: (0,4,0) ICIR 
1009: (2,0,2) 
1010: None
1011: (0,2,4) 
1012: (2,2,0) ICIR
1013: (4,0,0) ICIR
''')
# Out:
# f Eigenstates:
# 1002: trap
# 1003: (0,2,0) ICIR
# 1004: (0,0,4)
# 1005: (2,0,0) ICIR
# 1006: (0,0,6)
# 1007: (0,2,2)
# 1008: (0,4,0) ICIR
# 1009: (2,0,2)
# 1010: None
# 1011: (0,2,4)
# 1012: (2,2,0) ICIR
# 1013: (4,0,0) ICIR

# %%
print(f'''To find the eigenstates:
x={x[220]}, delta=0{delta[220]}
x={x[177]}, delta=0{delta[177]}
x={x[150]}, delta=0{delta[150]}
x={x[100]}, delta=0{delta[100]}
x={x[60]}, delta=0{delta[60]}
x={x[45]}, delta=0{delta[45]}
''')
# Out:
# To find the eigenstates:
# x=0.18127366824595584, delta=0.71430
# x=0.6236593558528052, delta=0.71215
# x=0.8979050545010485, delta=0.71080
# x=1.398781716951159, delta=0.70830
# x=1.7931335608113992, delta=0.70630
# x=1.939596870945855, delta=0.70555

# %%
# %matplotlib inline

# %% [markdown]
# # (2,0,0) (0,2,0)

# %%
fig3, ax3 = plt.subplots(figsize=(8,6))
# nivel 1002:
trap_poly = trap_fit(dic, x, x_lims=(0.15, 1.4), y_lims=(3.35, 3.65) ,levels=(1002, 1005), tol=3, wy=wy)/wy
x1002 = np.linspace(0.25, 1.95, num=20)
ax3.scatter(x1002, np.polyval(trap_poly, x1002), edgecolor='r', facecolor='C1', label='Diabatic', zorder=1)
ax3.plot(x, dic['nivel_1002']/wy, 'C0', label='Adiabatic', zorder=2)

# nivel 1003:
ax3.plot(x, dic['nivel_1003']/wy, 'C0', zorder=1)
f1003 = np.polyfit(x[(x < 0.60) & (x > 0.40)], np.array(dic['nivel_1002'])[(x < 0.60) & (x > 0.40)]/wy, deg=1)
x1003 = np.linspace(0.25, 1.95, num=50)
ax3.scatter(x1003, np.polyval(f1003, x1003), edgecolor='r', facecolor='C1', zorder=2)

# nivel 1004:
ax3.plot(x, dic['nivel_1004']/wy, 'C0', zorder=1)
f1004 = np.polyfit(x[(x < 1.07) & (x > 0.99)], np.array(dic['nivel_1003'])[(x < 1.07) & (x > 0.99)]/wy, deg=1)
x1004 = np.linspace(0.25, 1.95, num=50)
ax3.scatter(x1004, np.polyval(f1004, x1004), edgecolor='r', facecolor='C1', zorder=2)

# nivel 1005:
ax3.plot(x, dic['nivel_1005']/wy, 'C0', zorder=1)
f1005 = np.polyfit(x[(x < 1.1) & (x > 1.05)], np.array(dic['nivel_1004'])[(x < 1.1) & (x > 1.05)]/wy, deg=1)
x1005 = np.linspace(0.25, 1.95, num=50)
ax3.scatter(x1005, np.polyval(f1005, x1005), edgecolor='r', facecolor='C1', zorder=2)

# Crosses:
##########
ax3.plot(cross_points(trap_poly, f1003), np.polyval(trap_poly, cross_points(trap_poly, f1003)), 'w*', markersize=16, markeredgecolor='k', label='ICIR')
ax3.plot(cross_points(trap_poly, f1005), np.polyval(trap_poly, cross_points(trap_poly, f1005)), 'w*', markersize=16, markeredgecolor='k')

# States:
#########
ax3.annotate(r'$\left|\psi^{(1)} \Phi_{(0,0,0)}\right>$', xy=(0.605, 3.484), xytext=(0.55, 3.54), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,2,0)}\right>$', xy=(0.59, 3.366), xytext=(0.31, 3.36), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,0,4)}\right>$', xy=(1.05, 3.355), xytext=(0.74, 3.36), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,0,0)}\right>$', xy=(1, 3.46), xytext=(1.13, 3.47), fontsize=14, 
             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.set_xlabel('$d_{y}/a_{sc}$')
ax3.set_ylabel('$E[\hbar \omega_{y}]$')
ax3.xaxis.set_minor_locator(AutoMinorLocator())
ax3.yaxis.set_minor_locator(AutoMinorLocator())
ax3.set_ylim(3.33, 3.64)
ax3.set_xlim(0.15, 1.4)
#fig3.savefig('Results/Figures/LiLi_1d3d_7802_Easc_Interpolation_200_v2.png', bbox_inches="tight", dpi=200)
# Out:
# 9.188165758489922e-14
# (0.15, 1.4)

# %%
print(f'''Crosses between (x, E):
* trap-(0,2,0): ({cross_points(trap_poly, f1003)}, {np.polyval(trap_poly, cross_points(trap_poly, f1003))})
* trap-(2,0,0): ({cross_points(trap_poly, f1005)}, {np.polyval(trap_poly, cross_points(trap_poly, f1005))})
''')
# Out:
# Crosses between (x, E):
# * trap-(0,2,0): (0.3897332178186917, 3.5323961301661044)
# * trap-(2,0,0): (1.0268908067725409, 3.4076175842649716)

# %%
print(f'''ICIR: asc/dy:
* trap-(0,2,0): {1/cross_points(trap_poly, f1003)} 
* trap-(2,0,0): {1/cross_points(trap_poly, f1005)} 
''')
# Out:
# ICIR: asc/dy:
# * trap-(0,2,0): 2.565857756741719
# * trap-(2,0,0): 0.973813372760579

# %% [markdown]
# # $$(4,0,0) (0,4,0)$$

# %%
fig3, ax3 = plt.subplots(figsize=(8,6))
# nivel 1007:
ax3.plot(x, dic['nivel_1007']/wy, 'C0', zorder=1)
trap_poly = trap_fit(dic, x, x_lims=(1, 2), y_lims=(2.95, 3.28) ,levels=(1007, 1013), tol=10, wy=wy)/wy
x1007 = np.linspace(1, 2.28, num=50)
ax3.scatter(x1007, np.polyval(trap_poly, x1007), edgecolor='r', facecolor='C1', label='Diabatic', zorder=1)

# nivel 1008:
ax3.plot(x, dic['nivel_1008']/wy, 'C0', zorder=1)
f1008 = np.polyfit(x[(x < 1.84) & (x > 1.80)], np.array(dic['nivel_1007'])[(x < 1.84) & (x > 1.80)]/wy, deg=1)
x1008 = np.linspace(1.8, 1.9, num=30)
ax3.scatter(x1008, np.polyval(f1008, x1008), edgecolor='r', facecolor='C1', zorder=2)

# nivel 1009:
ax3.plot(x, dic['nivel_1009']/wy, 'C0', zorder=1)

# nivel 1010:
ax3.plot(x, dic['nivel_1010']/wy, 'C0', zorder=1)

# nivel 1011:
ax3.plot(x, dic['nivel_1011']/wy, 'C0', zorder=1)
f1011 = np.polyfit(x[(x < 2.1) & (x > 1.93)], np.array(dic['nivel_1011'])[(x < 2.1) & (x > 1.93)]/wy, deg=1)
x1011 = np.linspace(1.9, 2.2, num=100)
ax3.scatter(x1011, np.polyval(f1011, x1011), edgecolor='r', facecolor='C1', zorder=2)
                                                                          
# nivel 1012:
ax3.plot(x, dic['nivel_1012']/wy, 'C0', zorder=1)
                                                                          
# nivel 1013:
ax3.plot(x, dic['nivel_1013']/wy, 'C0', zorder=1)
f1013 = np.polyfit(x[(x < 2.28) & (x > 1.95)], np.array(dic['nivel_1013'])[(x < 2.28) & (x > 1.95)]/wy, deg=1)
x1013 = np.linspace(1.9, 2.28, num=100)
ax3.scatter(x1013, np.polyval(f1013, x1013), edgecolor='r', facecolor='C1', zorder=2)
                                                                           
# Crosses:
##########
ax3.plot(cross_points(trap_poly, f1009), np.polyval(trap_poly, cross_points(trap_poly, f1009)), 'w*',\
         markersize=16, markeredgecolor='k', label='ICIR')
ax3.plot(cross_points(trap_poly, f1011), np.polyval(trap_poly, cross_points(trap_poly, f1011)), 'w*',\
         markersize=16, markeredgecolor='k', label='ICIR')
ax3.plot(cross_points(trap_poly, f1013), np.polyval(trap_poly, cross_points(trap_poly, f1013)), 'w*',\
         markersize=16, markeredgecolor='k')

# States:
#########
#ax3.annotate(r'$\left|\psi^{(1)} \Phi_{(0,0,0)}\right>$', xy=(1.896, 3.20), xytext=(1.85, 3.19), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(0,4,0)}\right>$', xy=(1.85, 3.171), xytext=(1.88, 3.171), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(2,2,0)}\right>$', xy=(2.09, 3.202), xytext=(1.99, 3.202), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))
#
#ax3.annotate(r'$\left|\psi^{(b)} \Phi_{(4,0,0)}\right>$', xy=(2.19, 3.16), xytext=(2.01, 3.16), fontsize=14, 
#             bbox=dict(boxstyle="round", alpha=0.3, facecolor='C1'),
#             arrowprops=dict(arrowstyle="wedge, tail_width=0.5", alpha=0.3, facecolor='C1'))

ax3.set_xlabel('$d_{y}/a_{sc}$')
ax3.set_ylabel('$E[\hbar \omega_{y}]$')
ax3.xaxis.set_minor_locator(AutoMinorLocator())
ax3.yaxis.set_minor_locator(AutoMinorLocator())
ax3.set_ylim(3.20, 3.28)
ax3.set_xlim(1.76, 2.26)
#fig3.savefig('Results/Figures/LiLi_1d3d_7802_Easc_Interpolation_400_v2.png', bbox_inches="tight", dpi=200)
# Out:
# 7.716538316820571e-14
# (1.76, 2.26)

# %%
print(f'''Crosses between (x, E):
* trap-(0,4,0): ({cross_points(trap_poly, f1008)}, {np.polyval(trap_poly, cross_points(trap_poly, f1008))})
* trap-(2,2,0): ({cross_points(trap_poly, f1011)}, {np.polyval(trap_poly, cross_points(trap_poly, f1011))})
* trap-(4,0,0): ({cross_points(trap_poly, f1013)}, {np.polyval(trap_poly, cross_points(trap_poly, f1013))})
''')
# Out:
# Crosses between (x, E):
# * trap-(0,4,0): (1.8036534297418834, 3.269202286101158)
# * trap-(2,2,0): (2.118875307688158, 3.2253721493198935)
# * trap-(4,0,0): (2.254878635383259, 3.206461518831868)

# %%
print(f'''ICIR: asc/dy:
* trap-(0,4,0): {1/cross_points(trap_poly, f1008)} 
* trap-(2,2,0): {1/cross_points(trap_poly, f1011)} 
* trap-(4,0,0): {1/cross_points(trap_poly, f1013)}
''')
# Out:
# ICIR: asc/dy:
# * trap-(0,4,0): 0.5544302378218567
# * trap-(2,2,0): 0.47194848907417314
# * trap-(4,0,0): 0.443482848392872
